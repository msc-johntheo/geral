# %% [markdown]
# # Tarefa 02: Classificação através de Redes Neurais e Fuzzy
# Alunos:
# @ Elizianne Marinho Branches Farias
# @ Tiago Buatim Nion da Silveira
#
# Classificação de cédulas bancárias utilizando como entrada os parâmetros da transformada wavelet da imagem da cédula. Os dados utilizados são provenientes do *UCI Repository*. Deseja-se definir duas soluções diferentes para o problema de classificação, uma utilizando redes neurais e outra em sistemas fuzzy. Para tanto, as seguintes etapas de análise e classificação serão conduzidas:
#
# **[I. Pré-processamento](#I)**
# [1.1. Importando os dados](#1.1)
# [1.2. Análise, verificação e limpeza dos dados](#1.2)
# [1.3. Correção de prevalência (balanceamento)](#1.3)
# [1.4. Particionando a base de dados](#1.4)
#
# **[II. Classificador baseado em redes neurais](#II)**
# [2.1 Multi-Layer Perceptron utilizando Scikit-Learning](#2.1)
# [2.2 Comparação do desempenho do classificador MLP com diferentes parâmetros](#2.2)
#
# **[III. Classificador baseado em sistemas fuzzy](#III)**

# %% [markdown]
# ## I. Pré-processamento <a class="anchor" id="I"></a>

# %%
## Bibliotecas necessárias à execução do caderno:
import numpy as np  #Métodos matemáticos para computação científica
import pandas as pd  #Python Data Analysis Library
import matplotlib.pyplot as plt  #Visualização de dados
# %matplotlib inline
import seaborn as sns  #Visualização renderizada

# %% [markdown]
# ### 1.1 Importando os dados <a class="anchor" id="1.1"></a>
# Os dados são importados de um arquivo texto, tabulados por vírgula, com os seguintes atributos de entrada (informações da transformada Wavelet da imagem):
# 1.variance of Wavelet Transformed image (continuous)
# 2.skewness of Wavelet Transformed image (continuous)
# 3.curtosis of Wavelet Transformed image (continuous)
# 4.entropy of image (continuous)
#
# A saída já está discriminada no conjunto de dados, sendo:
# class (integer): 0 autêntica 1 falsificada

# %%
## Leitura do arquivo de entrada:
money = pd.read_csv('../fuzzy_rn_classif/dados_autent_bancaria.txt', sep=',',
                   names=['varCWT', 'skewCWT', 'curtCWT', 'entropy', 'class'])  #Cabeçalho incluído manualmente

# %%
## Exibição das primeiras linhas da base de dados:
money.head(3)
# Out:
#    varCWT  skewCWT  curtCWT  entropy  class
# 0  3.6216   8.6661  -2.8073 -0.44699      0
# 1  4.5459   8.1674  -2.4586 -1.46210      0
# 2  3.8660  -2.6383   1.9242  0.10645      0

# %% [markdown]
# ### 1.2 Análise, verificação e limpeza dos dados: <a class="anchor" id="1.2"></a>
# Esta etapa tem por objetivo fornecer uma descrição geral do conjunto de dados a ser trabalhado, permitindo a observação de *outliers*, por exemplo, e facilitando a posterior aplicação de modelos. Conforme o enunciado da tarefa, deve-se também avaliar a consistência dos dados (i.e. mesmas entradas apresentando saídas distintas), uma vez que inconsistências podem levar à não convergência dos classificadores.

# %%
## Pairplot para visão geral do conjunto de dados:
sns.pairplot(money, hue="class", vars=['varCWT', 'skewCWT', 'curtCWT', 'entropy'])

# %%
## Verificando quantidade de registros e existência de elementos nulos:
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
# varCWT     1372 non-null float64
# skewCWT    1372 non-null float64
# curtCWT    1372 non-null float64
# entropy    1372 non-null float64
# class      1372 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %% [markdown]
# #### Consistência dos dados:

# %%
## Verificando a existência de registros duplicados:
duplicadas = money.duplicated(subset=['varCWT', 'skewCWT', 'curtCWT', 'entropy'], keep=False)
#O parâmetro "keep=False" é utilizado para que todos os registros repetidas sejam considerados, permitindo avaliar a classe
duplicadas.value_counts()
# Out:
# False    1337
# True       35
# dtype: int64

# %%
## Inspeção dos valores, se há divergência na atribuição de classes para entradas idênticas:
money[duplicadas]['class'].describe()
# Out:
# count    35.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: class, dtype: float64

# %%
## Não havendo divergência (no resultado acima há apenas a classe 0), serão removidas apenas um dos registros duplicados:
money.drop_duplicates(subset=['varCWT', 'skewCWT', 'curtCWT', 'entropy'], keep='first', inplace=True)

# %%
## Gera um novo índice após a remoção das linhas duplicadas:
money.reset_index(inplace=True)

# %%
## Verificação do conjunto após a remoção, agora sem nenhum registro duplicado:
money[money.duplicated(subset=['varCWT', 'skewCWT', 'curtCWT', 'entropy'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [index, varCWT, skewCWT, curtCWT, entropy, class]
# Index: []

# %% [markdown]
# ### 1.3 Correção de prevalência (balanceamento) <a class="anchor" id="1.3"></a>
#
# #### Quão balanceadas estão as classes?
# Para o problema em questão há duas classes possíveis: (0) quando as notas são verdadeiras; e (1) quando as notas são falsas. É importante sabermos se no conjunto de dados trabalhado as classes estão distribuídas uniformemente. Para tanto, um histograma com a distribuição dos valores da classe pode ser construído ou, uma vez que só há dois valores possíveis, a própria contagem dos mesmos já é o suficiente. Caso não estejam balanceadas, há diferentes técnicas (fora do escopo deste trabalho) para realizar uma amostragem adequada.

# %%
## Contagem do número de instâncias por classe:
print('Instâncias classificadas como autênticas:', len(money.loc[money['class'] == 0]))
print('Instâncias classificadas como falsificadas:', len(money.loc[money['class'] == 1]))
# Out:
# Instâncias classificadas como autênticas: 738
# Instâncias classificadas como falsificadas: 610

# %% [markdown]
# #### Como as instânciasde cada classe estão distribuídas no conjunto de dados?
# Para esta questão, simplesmente *plotar* o atributo *class* da base de dados é suficiente para determinar se as classes já estão separadas ou se estão aleatórias. Conforme mostrado abaixo, as primeiras 738 instâncias pertencem à classe de notas autênticas, enquanto as próximas 610 à classe de notas falsificadas.

# %%
plt.figure(figsize=(5,2))
plt.plot(money['class'])

# %% [markdown]
# #### Decisão quanto ao balanceamento:
# Dado o tamanho do conjunto e a variação de 17.3% no número de registros entre as classes (610/738), a atual distribuição de classes poderia ser considerada satisfatória. Entretanto, considerando as especificações da tarefa para a composição do conjunto de treino e teste, um novo *dataframe* será constituído com uma distribuição homogênea das classes (ver [Seção 1.4](#1.4)):

# %%
## Copiando o dataframe: 
pmoney = money.copy()
pmoney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 6 columns):
# index      1348 non-null int64
# varCWT     1348 non-null float64
# skewCWT    1348 non-null float64
# curtCWT    1348 non-null float64
# entropy    1348 non-null float64
# class      1348 non-null int64
# dtypes: float64(4), int64(2)
# memory usage: 63.3 KB

# %%
## Escolha aleatória de 128 (738-610) istâncias da classe 0 para serem removidas (balanceamento):
ixRow2drop = np.arange(len(pmoney.loc[pmoney['class']==0])) #Cria uma lista de 0 a len(class) - Índices previamente ordenados;
np.random.shuffle(ixRow2drop)  #Embaralha as posições dos índices;
ixRow2drop = ixRow2drop[:128]  #Seleciona as primeiras 128 amostras da lista de índice;

# %%
## Remove do dataframe pmoney as amostras selecionadas aleatoriamente na etapa anterior:
pmoney.drop(ixRow2drop, inplace=True)
pmoney.reset_index(inplace=True)  #Reordena o índice após a remoção das linhas
pmoney.info()
## Exibindo o número de instâncias por classe do conjunto *pmoney*, agora homogêneo:
print('\nInstâncias classificadas como autênticas:', len(pmoney.loc[pmoney['class'] == 0]))
print('Instâncias classificadas como falsificadas:', len(pmoney.loc[pmoney['class'] == 1]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 7 columns):
# level_0    1220 non-null int64
# index      1220 non-null int64
# varCWT     1220 non-null float64
# skewCWT    1220 non-null float64
# curtCWT    1220 non-null float64
# entropy    1220 non-null float64
# class      1220 non-null int64
# dtypes: float64(4), int64(3)
# memory usage: 66.8 KB
#
# Instâncias classificadas como autênticas: 610
# Instâncias classificadas como falsificadas: 610

# %% [markdown]
# ### 1.4 Particionando a base de dados: <a class="anchor" id="1.4"></a>
# De acordo com o enunciado da tarefa, é necessário "definir Conjunto de treinamento: 40% da classe 1 + 40% da classe 0. O conjunto de treinamento poderá ainda ser particionado em Tr mais validação (para o treinamento das RN). Definir Conjunto de teste: 10% da classe 1 + 10% da classe 0".
# Sendo assim, a partir do conjunto *pmoney* já balanceado com 1220 amostras, serão selecionadas aleatoriamente (através do método *np.random.shuffle*) as 976 amostras do conjunto de treino e 244 amostras do conjunto de teste. Ainda, para a aplicação de redes neurais, o conjunto de treino será particionado em *treino + validação* utilizando a técnica k-fold.

# %%
## Seleção das amostras de treino e teste da classe 0:
ixClass0 = pmoney.loc[pmoney['class']==0].index.values  #Cria uma lista com os índices das instâncias pertencentes à classe 0;
np.random.shuffle(ixClass0)  #Embaralha as posições dos índices;
ixTreino0 = ixClass0[:488]  #Seleciona as primeiras 488 amostras da lista de índice para treino;
ixTeste0 = ixClass0[488:610]  #Seleciona as 122 amostras restantes para teste.

## Seleção das amostras de treino e teste da classe 1:
ixClass1 = pmoney.loc[pmoney['class']==1].index.values  #Cria uma lista com os índices das instâncias pertencentes à classe 1;
np.random.shuffle(ixClass1)  #Embaralha as posições dos índices;
ixTreino1 = ixClass1[:488]  #Seleciona as primeiras 488 amostras da lista de índice para treino;
ixTeste1 = ixClass1[488:610]  #Seleciona as 122 amostras restantes para teste.

## Índice conjunto de treino:
ixTreino = np.concatenate((ixTreino0, ixTreino1))
ixTeste = np.concatenate((ixTeste0, ixTeste1))

# %%
## Definição do conjunto de treino:
treino = pmoney.loc[ixTreino]
## Definição do conjunto de teste:
teste = pmoney.loc[ixTeste]

# %%
## Verificação dos conjuntos particionados: 
print('Quantidade de instâncias no conjunto "Treino":', len(treino))
print('\tClasse0:', len(treino.loc[treino['class'] == 0]))
print('\tClasse1:', len(treino.loc[treino['class'] == 1]))
print('\nQuantidade de instâncias no conjunto "Teste":', len(teste))
print('\tClasse0', len(teste.loc[teste['class'] == 0]))
print('\tClasse1', len(teste.loc[teste['class'] == 1]))
# Out:
# Quantidade de instâncias no conjunto "Treino": 976
# 	Classe0: 488
# 	Classe1: 488
#
# Quantidade de instâncias no conjunto "Teste": 244
# 	Classe0 122
# 	Classe1 122

# %% [markdown]
# ## II. Classificador baseado em redes neurais <a class="anchor" id="II"></a>
# Nesta tarefa, a rede neural utilizada como classificador é a *MLP - MultiLayer Perceptron*, treinada pelo algoritmo de *backpropagation*. Para a tarefa é requerido testar diferentes estruturas de redes neurais (camadas ocultas e números de neurônios em cada camada oculta, função de ativação, parâmetros do algoritmo de treinamento, dados de validação, uso do bias, entre outros).
#
# Classificador MLP: http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html

# %%
from sklearn.neural_network import MLPClassifier  #Redes neurais: classificador MLP
from sklearn.cross_validation import KFold  #Validação cruzada utilizando k-fold
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
import sklearn
sklearn.__version__
# Out:
# /home/anaconda3/envs/python3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# '0.18.1'

# %% [markdown]
# ### 2.1 Multi-Layer Perceptron utilizando Scikit-Learning <a class="anchor" id="2.1"></a>

# %% [markdown]
# Baseado nos comentários de Robi Polikar, optou-se por utilizar *k-fold cross validation*, com k=10. Esta técnica consiste em dividir o conjunto de treino em *k* partes, realizando *k* iterações de treino do classificador. Em cada iteração, a k-ésima subparte é considerada o conjunto de validação, enquanto as 'k-1' partes restantes são consideradas como o conjunto de treino.

# %%
kf = KFold(treino.shape[0], n_folds=10, random_state=1)

# %%
## Atributos considerados no treinamento:
features = ['varCWT', 'skewCWT', 'curtCWT', 'entropy']

# %% [markdown]
# #### Definindo os parâmetros da rede MLP:
# Referência completa: http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier
#
# - ***hidden_layer_sizes***: é uma tupla onde cada elemento representa o número de neurônios na respectiva camada. E.g. hidden_layer_sizes=(10,10) representa uma rede MLP com duas camadas ocultas contendo 10 neurônios cada qual.
# - ***activation***: escolha da função de ativação para as camadas ocultas, admitindo as opções *identity, logistic, tanh* e *relu* (consultar a referência para o detalhe de cada função). Para este trabalho foi escolhida a função *logistic*, uma vez que possui a mesma saída da função sigmoidal.
# - ***solver***: esta implementação permite diferentes 'solucionadores'. A opção escolhida corresponde ao *stochastic gradient descent*, similar ao algoritmo estudado em aula.
# - ***learning_rate*** e ***learning_rate_init***: corresponde ao modo de variação/adaptação da taxa de aprendizado, bem como à definição do seu valor inicial.
# - ***momentum***: recurso utilizado para se evitar os mínimos locais no treinamento da rede. Conforme sugerido em aula, o valor escolhido é de 0.9. Há o recurso de se aplicar o "Nesterov's momentum", resultando em maior otimização (Ver https://stats.stackexchange.com/questions/179915/whats-the-difference-between-momentum-based-gradient-descent-and-nesterovs-ac)
# - ***max_iter***: número máximo de iterações. Esta implementação, no entanto, interrompe a iteração quando não houver alteração na função de perda ao decorrer de duas épocas. O valor é definido através do parâmetro ***tol***.
#
# Além destes, há outros parâmetros que podem ser definidos, conforme visto abaixo na saída do comando *neural_clf.get_params*. Nesta implementação, no entanto, não foi encontrada a possibilidade de se definir os valores iniciais de bias e dos pesos. Ao final do treinamento, porém, os mesmos podem ser verificados através dos atributos *intercepts_* e *coefs_*, respectivamente.

# %%
## O classificador MLP é definido com os seguintes parâmetros:
neural_clf = MLPClassifier(hidden_layer_sizes=(10,10), 
                           activation='logistic', 
                           solver='sgd',
                           learning_rate='constant', 
                           learning_rate_init=0.01,
                           momentum=0.9, 
                           max_iter=1000, 
                           verbose=True)

# %%
## Verificação de todos os parâmetros (passados ou por padrão) do classificador neural MLP:
neural_clf.get_params
# Out:
# <bound method BaseEstimator.get_params of MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(10, 10), learning_rate='constant',
#        learning_rate_init=0.01, max_iter=1000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='sgd', tol=0.0001, validation_fraction=0.1,
#        verbose=True, warm_start=False)>

# %% [markdown]
# #### Treinamento da rede MLP:

# %%
predictions = []
for train, test in kf:
    train_predictors = (treino[features].iloc[train,:])  # The predictors we're using the train the algorithm.
    train_target = treino['class'].iloc[train]            # The target we're using to train the algorithm.
    # Training the algorithm using the predictors and target.
    neural_clf.fit(train_predictors, train_target)
    # We can now make predictions on the test fold
    test_predictions = neural_clf.predict(treino[features].iloc[test,:])
    predictions.append(test_predictions)
# Out:
# Iteration 1, loss = 0.66637927
# Iteration 2, loss = 0.66562596
# Iteration 3, loss = 0.66449288
# Iteration 4, loss = 0.66319506
# Iteration 5, loss = 0.66171444
# Iteration 6, loss = 0.66022022
# Iteration 7, loss = 0.65842750
# Iteration 8, loss = 0.65658131
# Iteration 9, loss = 0.65455789
# Iteration 10, loss = 0.65251570
# Iteration 11, loss = 0.65035113
# Iteration 12, loss = 0.64817754
# Iteration 13, loss = 0.64545561
# Iteration 14, loss = 0.64276011
# Iteration 15, loss = 0.63988032
# Iteration 16, loss = 0.63705311
# Iteration 17, loss = 0.63394403
# Iteration 18, loss = 0.63063570
# Iteration 19, loss = 0.62706946
# Iteration 20, loss = 0.62333922
# Iteration 21, loss = 0.61947640
# Iteration 22, loss = 0.61523279
# Iteration 23, loss = 0.61072621
# Iteration 24, loss = 0.60603423
# Iteration 25, loss = 0.60116049
# Iteration 26, loss = 0.59593817
# Iteration 27, loss = 0.59047177
# Iteration 28, loss = 0.58464850
# Iteration 29, loss = 0.57865447
# Iteration 30, loss = 0.57221870
# Iteration 31, loss = 0.56546703
# Iteration 32, loss = 0.55855156
# Iteration 33, loss = 0.55115068
# Iteration 34, loss = 0.54335502
# Iteration 35, loss = 0.53539001
# Iteration 36, loss = 0.52701653
# Iteration 37, loss = 0.51839944
# Iteration 38, loss = 0.50944682
# Iteration 39, loss = 0.50016319
# Iteration 40, loss = 0.49066039
# Iteration 41, loss = 0.48083558
# Iteration 42, loss = 0.47078913
# Iteration 43, loss = 0.46037002
# Iteration 44, loss = 0.44970196
# Iteration 45, loss = 0.43892869
# Iteration 46, loss = 0.42804274
# Iteration 47, loss = 0.41700322
# Iteration 48, loss = 0.40596852
# Iteration 49, loss = 0.39475852
# Iteration 50, loss = 0.38363070
# Iteration 51, loss = 0.37238409
# Iteration 52, loss = 0.36126262
# Iteration 53, loss = 0.35029227
# Iteration 54, loss = 0.33942809
# Iteration 55, loss = 0.32870927
# Iteration 56, loss = 0.31814724
# Iteration 57, loss = 0.30780244
# Iteration 58, loss = 0.29775969
# Iteration 59, loss = 0.28793407
# Iteration 60, loss = 0.27834244
# Iteration 61, loss = 0.26912270
# Iteration 62, loss = 0.26012566
# Iteration 63, loss = 0.25147611
# Iteration 64, loss = 0.24303894
# Iteration 65, loss = 0.23491160
# Iteration 66, loss = 0.22719572
# Iteration 67, loss = 0.21965957
# Iteration 68, loss = 0.21256403
# Iteration 69, loss = 0.20569074
# Iteration 70, loss = 0.19907297
# Iteration 71, loss = 0.19279119
# Iteration 72, loss = 0.18672107
# Iteration 73, loss = 0.18092347
# Iteration 74, loss = 0.17536531
# Iteration 75, loss = 0.17006249
# Iteration 76, loss = 0.16500802
# Iteration 77, loss = 0.16010533
# Iteration 78, loss = 0.15545737
# Iteration 79, loss = 0.15103150
# Iteration 80, loss = 0.14673347
# Iteration 81, loss = 0.14263144
# Iteration 82, loss = 0.13873731
# Iteration 83, loss = 0.13495820
# Iteration 84, loss = 0.13138127
# Iteration 85, loss = 0.12794371
# Iteration 86, loss = 0.12465426
# Iteration 87, loss = 0.12147356
# Iteration 88, loss = 0.11844773
# Iteration 89, loss = 0.11549014
# Iteration 90, loss = 0.11269036
# Iteration 91, loss = 0.10999065
# Iteration 92, loss = 0.10741826
# Iteration 93, loss = 0.10493865
# Iteration 94, loss = 0.10256742
# Iteration 95, loss = 0.10028603
# Iteration 96, loss = 0.09806764
# Iteration 97, loss = 0.09592603
# Iteration 98, loss = 0.09392765
# Iteration 99, loss = 0.09193532
# Iteration 100, loss = 0.09002650
# Iteration 101, loss = 0.08816574
# Iteration 102, loss = 0.08640709
# Iteration 103, loss = 0.08466707
# Iteration 104, loss = 0.08301167
# Iteration 105, loss = 0.08140097
# Iteration 106, loss = 0.07985935
# Iteration 107, loss = 0.07839631
# Iteration 108, loss = 0.07696125
# Iteration 109, loss = 0.07559701
# Iteration 110, loss = 0.07425588
# Iteration 111, loss = 0.07293626
# Iteration 112, loss = 0.07168525
# Iteration 113, loss = 0.07047071
# Iteration 114, loss = 0.06927793
# Iteration 115, loss = 0.06814667
# Iteration 116, loss = 0.06703432
# Iteration 117, loss = 0.06592414
# Iteration 118, loss = 0.06490807
# Iteration 119, loss = 0.06388352
# Iteration 120, loss = 0.06290688
# Iteration 121, loss = 0.06195267
# Iteration 122, loss = 0.06103634
# Iteration 123, loss = 0.06013711
# Iteration 124, loss = 0.05925515
# Iteration 125, loss = 0.05845071
# Iteration 126, loss = 0.05761411
# Iteration 127, loss = 0.05679667
# Iteration 128, loss = 0.05602082
# Iteration 129, loss = 0.05527301
# Iteration 130, loss = 0.05453262
# Iteration 131, loss = 0.05384550
# Iteration 132, loss = 0.05308542
# Iteration 133, loss = 0.05241329
# Iteration 134, loss = 0.05176900
# Iteration 135, loss = 0.05111399
# Iteration 136, loss = 0.05047823
# Iteration 137, loss = 0.04985701
# Iteration 138, loss = 0.04926181
# Iteration 139, loss = 0.04868602
# Iteration 140, loss = 0.04809339
# Iteration 141, loss = 0.04757111
# Iteration 142, loss = 0.04700690
# Iteration 143, loss = 0.04646838
# Iteration 144, loss = 0.04597050
# Iteration 145, loss = 0.04544234
# Iteration 146, loss = 0.04496802
# Iteration 147, loss = 0.04449333
# Iteration 148, loss = 0.04401119
# Iteration 149, loss = 0.04356089
# Iteration 150, loss = 0.04311963
# Iteration 151, loss = 0.04264480
# Iteration 152, loss = 0.04222565
# Iteration 153, loss = 0.04181134
# Iteration 154, loss = 0.04138127
# Iteration 155, loss = 0.04098754
# Iteration 156, loss = 0.04058851
# Iteration 157, loss = 0.04019593
# Iteration 158, loss = 0.03982440
# Iteration 159, loss = 0.03945087
# Iteration 160, loss = 0.03910563
# Iteration 161, loss = 0.03873922
# Iteration 162, loss = 0.03839233
# Iteration 163, loss = 0.03804486
# Iteration 164, loss = 0.03771153
# Iteration 165, loss = 0.03740407
# Iteration 166, loss = 0.03705901
# Iteration 167, loss = 0.03674901
# Iteration 168, loss = 0.03644722
# Iteration 169, loss = 0.03612018
# Iteration 170, loss = 0.03586127
# Iteration 171, loss = 0.03555237
# Iteration 172, loss = 0.03524818
# Iteration 173, loss = 0.03495752
# Iteration 174, loss = 0.03469556
# Iteration 175, loss = 0.03441632
# Iteration 176, loss = 0.03415856
# Iteration 177, loss = 0.03392659
# Iteration 178, loss = 0.03364572
# Iteration 179, loss = 0.03339142
# Iteration 180, loss = 0.03314945
# Iteration 181, loss = 0.03288840
# Iteration 182, loss = 0.03266538
# Iteration 183, loss = 0.03243059
# Iteration 184, loss = 0.03219361
# Iteration 185, loss = 0.03196590
# Iteration 186, loss = 0.03174550
# Iteration 187, loss = 0.03155746
# Iteration 188, loss = 0.03129848
# Iteration 189, loss = 0.03109148
# Iteration 190, loss = 0.03090794
# Iteration 191, loss = 0.03070847
# Iteration 192, loss = 0.03051789
# Iteration 193, loss = 0.03031408
# Iteration 194, loss = 0.03013058
# Iteration 195, loss = 0.02992563
# Iteration 196, loss = 0.02971302
# Iteration 197, loss = 0.02951938
# Iteration 198, loss = 0.02933069
# Iteration 199, loss = 0.02922775
# Iteration 200, loss = 0.02900134
# Iteration 201, loss = 0.02879053
# Iteration 202, loss = 0.02860521
# Iteration 203, loss = 0.02844554
# Iteration 204, loss = 0.02829048
# Iteration 205, loss = 0.02816082
# Iteration 206, loss = 0.02799057
# Iteration 207, loss = 0.02780843
# Iteration 208, loss = 0.02762255
# Iteration 209, loss = 0.02745664
# Iteration 210, loss = 0.02730568
# Iteration 211, loss = 0.02714173
# Iteration 212, loss = 0.02699580
# Iteration 213, loss = 0.02685506
# Iteration 214, loss = 0.02670476
# Iteration 215, loss = 0.02655599
# Iteration 216, loss = 0.02640425
# Iteration 217, loss = 0.02625745
# Iteration 218, loss = 0.02612783
# Iteration 219, loss = 0.02600994
# Iteration 220, loss = 0.02586683
# Iteration 221, loss = 0.02576605
# Iteration 222, loss = 0.02556992
# Iteration 223, loss = 0.02544375
# Iteration 224, loss = 0.02531769
# Iteration 225, loss = 0.02518252
# Iteration 226, loss = 0.02504353
# Iteration 227, loss = 0.02491914
# Iteration 228, loss = 0.02479000
# Iteration 229, loss = 0.02467900
# Iteration 230, loss = 0.02453956
# Iteration 231, loss = 0.02443740
# Iteration 232, loss = 0.02430963
# Iteration 233, loss = 0.02420592
# Iteration 234, loss = 0.02405831
# Iteration 235, loss = 0.02395924
# Iteration 236, loss = 0.02385329
# Iteration 237, loss = 0.02374187
# Iteration 238, loss = 0.02363225
# Iteration 239, loss = 0.02350222
# Iteration 240, loss = 0.02338748
# Iteration 241, loss = 0.02327657
# Iteration 242, loss = 0.02320343
# Iteration 243, loss = 0.02307466
# Iteration 244, loss = 0.02299824
# Iteration 245, loss = 0.02285488
# Iteration 246, loss = 0.02275965
# Iteration 247, loss = 0.02268342
# Iteration 248, loss = 0.02255379
# Iteration 249, loss = 0.02247278
# Iteration 250, loss = 0.02236875
# Iteration 251, loss = 0.02227124
# Iteration 252, loss = 0.02216558
# Iteration 253, loss = 0.02205899
# Iteration 254, loss = 0.02201544
# Iteration 255, loss = 0.02188158
# Iteration 256, loss = 0.02180218
# Iteration 257, loss = 0.02171690
# Iteration 258, loss = 0.02160376
# Iteration 259, loss = 0.02152742
# Iteration 260, loss = 0.02145351
# Iteration 261, loss = 0.02135159
# Iteration 262, loss = 0.02125232
# Iteration 263, loss = 0.02117771
# Iteration 264, loss = 0.02107380
# Iteration 265, loss = 0.02100728
# Iteration 266, loss = 0.02091707
# Iteration 267, loss = 0.02083077
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.67918843
# Iteration 2, loss = 0.67879809
# Iteration 3, loss = 0.67825444
# Iteration 4, loss = 0.67753978
# Iteration 5, loss = 0.67677376
# Iteration 6, loss = 0.67588726
# Iteration 7, loss = 0.67496332
# Iteration 8, loss = 0.67403536
# Iteration 9, loss = 0.67297467
# Iteration 10, loss = 0.67192161
# Iteration 11, loss = 0.67083094
# Iteration 12, loss = 0.66962956
# Iteration 13, loss = 0.66848621
# Iteration 14, loss = 0.66722231
# Iteration 15, loss = 0.66572021
# Iteration 16, loss = 0.66411813
# Iteration 17, loss = 0.66256581
# Iteration 18, loss = 0.66108267
# Iteration 19, loss = 0.65957242
# Iteration 20, loss = 0.65784186
# Iteration 21, loss = 0.65603607
# Iteration 22, loss = 0.65405489
# Iteration 23, loss = 0.65196478
# Iteration 24, loss = 0.64971226
# Iteration 25, loss = 0.64770015
# Iteration 26, loss = 0.64504914
# Iteration 27, loss = 0.64243454
# Iteration 28, loss = 0.63977338
# Iteration 29, loss = 0.63684731
# Iteration 30, loss = 0.63368930
# Iteration 31, loss = 0.63049641
# Iteration 32, loss = 0.62720791
# Iteration 33, loss = 0.62334950
# Iteration 34, loss = 0.61942131
# Iteration 35, loss = 0.61523117
# Iteration 36, loss = 0.61078000
# Iteration 37, loss = 0.60609139
# Iteration 38, loss = 0.60113001
# Iteration 39, loss = 0.59597942
# Iteration 40, loss = 0.59030296
# Iteration 41, loss = 0.58442920
# Iteration 42, loss = 0.57821363
# Iteration 43, loss = 0.57161863
# Iteration 44, loss = 0.56475407
# Iteration 45, loss = 0.55741555
# Iteration 46, loss = 0.54979076
# Iteration 47, loss = 0.54174405
# Iteration 48, loss = 0.53343773
# Iteration 49, loss = 0.52462532
# Iteration 50, loss = 0.51545725
# Iteration 51, loss = 0.50595726
# Iteration 52, loss = 0.49626637
# Iteration 53, loss = 0.48620491
# Iteration 54, loss = 0.47571028
# Iteration 55, loss = 0.46507995
# Iteration 56, loss = 0.45419132
# Iteration 57, loss = 0.44315866
# Iteration 58, loss = 0.43190184
# Iteration 59, loss = 0.42055718
# Iteration 60, loss = 0.40916692
# Iteration 61, loss = 0.39764257
# Iteration 62, loss = 0.38614721
# Iteration 63, loss = 0.37484859
# Iteration 64, loss = 0.36344579
# Iteration 65, loss = 0.35230421
# Iteration 66, loss = 0.34132485
# Iteration 67, loss = 0.33041868
# Iteration 68, loss = 0.31982093
# Iteration 69, loss = 0.30943424
# Iteration 70, loss = 0.29925423
# Iteration 71, loss = 0.28947837
# Iteration 72, loss = 0.27981144
# Iteration 73, loss = 0.27051464
# Iteration 74, loss = 0.26154101
# Iteration 75, loss = 0.25286880
# Iteration 76, loss = 0.24455391
# Iteration 77, loss = 0.23644378
# Iteration 78, loss = 0.22879162
# Iteration 79, loss = 0.22133903
# Iteration 80, loss = 0.21421603
# Iteration 81, loss = 0.20732219
# Iteration 82, loss = 0.20082100
# Iteration 83, loss = 0.19455543
# Iteration 84, loss = 0.18851342
# Iteration 85, loss = 0.18272926
# Iteration 86, loss = 0.17720730
# Iteration 87, loss = 0.17196551
# Iteration 88, loss = 0.16689405
# Iteration 89, loss = 0.16208147
# Iteration 90, loss = 0.15747355
# Iteration 91, loss = 0.15308760
# Iteration 92, loss = 0.14884466
# Iteration 93, loss = 0.14475522
# Iteration 94, loss = 0.14092408
# Iteration 95, loss = 0.13722957
# Iteration 96, loss = 0.13363174
# Iteration 97, loss = 0.13017482
# Iteration 98, loss = 0.12688129
# Iteration 99, loss = 0.12376420
# Iteration 100, loss = 0.12067059
# Iteration 101, loss = 0.11776620
# Iteration 102, loss = 0.11494987
# Iteration 103, loss = 0.11228482
# Iteration 104, loss = 0.10972835
# Iteration 105, loss = 0.10724817
# Iteration 106, loss = 0.10484763
# Iteration 107, loss = 0.10257523
# Iteration 108, loss = 0.10039211
# Iteration 109, loss = 0.09827350
# Iteration 110, loss = 0.09625175
# Iteration 111, loss = 0.09426197
# Iteration 112, loss = 0.09234601
# Iteration 113, loss = 0.09048037
# Iteration 114, loss = 0.08870792
# Iteration 115, loss = 0.08701838
# Iteration 116, loss = 0.08534601
# Iteration 117, loss = 0.08377365
# Iteration 118, loss = 0.08223749
# Iteration 119, loss = 0.08075041
# Iteration 120, loss = 0.07932934
# Iteration 121, loss = 0.07793260
# Iteration 122, loss = 0.07658304
# Iteration 123, loss = 0.07526467
# Iteration 124, loss = 0.07401487
# Iteration 125, loss = 0.07279591
# Iteration 126, loss = 0.07162731
# Iteration 127, loss = 0.07047986
# Iteration 128, loss = 0.06942120
# Iteration 129, loss = 0.06825763
# Iteration 130, loss = 0.06722423
# Iteration 131, loss = 0.06619759
# Iteration 132, loss = 0.06519315
# Iteration 133, loss = 0.06423479
# Iteration 134, loss = 0.06333006
# Iteration 135, loss = 0.06238831
# Iteration 136, loss = 0.06148507
# Iteration 137, loss = 0.06063732
# Iteration 138, loss = 0.05981165
# Iteration 139, loss = 0.05897769
# Iteration 140, loss = 0.05821745
# Iteration 141, loss = 0.05743011
# Iteration 142, loss = 0.05670455
# Iteration 143, loss = 0.05595260
# Iteration 144, loss = 0.05525033
# Iteration 145, loss = 0.05457153
# Iteration 146, loss = 0.05387208
# Iteration 147, loss = 0.05320159
# Iteration 148, loss = 0.05255934
# Iteration 149, loss = 0.05203871
# Iteration 150, loss = 0.05136055
# Iteration 151, loss = 0.05075709
# Iteration 152, loss = 0.05019466
# Iteration 153, loss = 0.04959859
# Iteration 154, loss = 0.04906456
# Iteration 155, loss = 0.04855936
# Iteration 156, loss = 0.04800049
# Iteration 157, loss = 0.04747459
# Iteration 158, loss = 0.04698004
# Iteration 159, loss = 0.04648105
# Iteration 160, loss = 0.04600077
# Iteration 161, loss = 0.04553737
# Iteration 162, loss = 0.04507574
# Iteration 163, loss = 0.04463046
# Iteration 164, loss = 0.04418579
# Iteration 165, loss = 0.04374658
# Iteration 166, loss = 0.04333102
# Iteration 167, loss = 0.04293545
# Iteration 168, loss = 0.04252570
# Iteration 169, loss = 0.04211506
# Iteration 170, loss = 0.04172954
# Iteration 171, loss = 0.04137443
# Iteration 172, loss = 0.04100294
# Iteration 173, loss = 0.04063073
# Iteration 174, loss = 0.04027343
# Iteration 175, loss = 0.03993409
# Iteration 176, loss = 0.03961657
# Iteration 177, loss = 0.03929601
# Iteration 178, loss = 0.03897140
# Iteration 179, loss = 0.03860526
# Iteration 180, loss = 0.03832411
# Iteration 181, loss = 0.03801233
# Iteration 182, loss = 0.03768408
# Iteration 183, loss = 0.03737494
# Iteration 184, loss = 0.03708278
# Iteration 185, loss = 0.03680215
# Iteration 186, loss = 0.03652681
# Iteration 187, loss = 0.03623280
# Iteration 188, loss = 0.03594483
# Iteration 189, loss = 0.03567730
# Iteration 190, loss = 0.03545449
# Iteration 191, loss = 0.03518583
# Iteration 192, loss = 0.03497801
# Iteration 193, loss = 0.03471095
# Iteration 194, loss = 0.03442420
# Iteration 195, loss = 0.03421462
# Iteration 196, loss = 0.03396413
# Iteration 197, loss = 0.03379335
# Iteration 198, loss = 0.03350004
# Iteration 199, loss = 0.03328627
# Iteration 200, loss = 0.03302816
# Iteration 201, loss = 0.03281982
# Iteration 202, loss = 0.03260872
# Iteration 203, loss = 0.03239619
# Iteration 204, loss = 0.03220154
# Iteration 205, loss = 0.03200747
# Iteration 206, loss = 0.03178693
# Iteration 207, loss = 0.03158272
# Iteration 208, loss = 0.03136224
# Iteration 209, loss = 0.03117439
# Iteration 210, loss = 0.03099527
# Iteration 211, loss = 0.03082803
# Iteration 212, loss = 0.03061258
# Iteration 213, loss = 0.03044870
# Iteration 214, loss = 0.03026511
# Iteration 215, loss = 0.03010393
# Iteration 216, loss = 0.02989851
# Iteration 217, loss = 0.02974370
# Iteration 218, loss = 0.02958667
# Iteration 219, loss = 0.02941241
# Iteration 220, loss = 0.02923430
# Iteration 221, loss = 0.02904883
# Iteration 222, loss = 0.02889599
# Iteration 223, loss = 0.02877033
# Iteration 224, loss = 0.02861001
# Iteration 225, loss = 0.02845612
# Iteration 226, loss = 0.02830735
# Iteration 227, loss = 0.02814279
# Iteration 228, loss = 0.02799086
# Iteration 229, loss = 0.02784122
# Iteration 230, loss = 0.02771561
# Iteration 231, loss = 0.02760363
# Iteration 232, loss = 0.02742816
# Iteration 233, loss = 0.02729781
# Iteration 234, loss = 0.02716704
# Iteration 235, loss = 0.02704791
# Iteration 236, loss = 0.02688264
# Iteration 237, loss = 0.02675640
# Iteration 238, loss = 0.02664486
# Iteration 239, loss = 0.02650602
# Iteration 240, loss = 0.02638931
# Iteration 241, loss = 0.02625516
# Iteration 242, loss = 0.02613134
# Iteration 243, loss = 0.02602271
# Iteration 244, loss = 0.02591073
# Iteration 245, loss = 0.02587052
# Iteration 246, loss = 0.02565684
# Iteration 247, loss = 0.02555039
# Iteration 248, loss = 0.02544102
# Iteration 249, loss = 0.02530976
# Iteration 250, loss = 0.02520575
# Iteration 251, loss = 0.02508491
# Iteration 252, loss = 0.02505951
# Iteration 253, loss = 0.02487410
# Iteration 254, loss = 0.02477716
# Iteration 255, loss = 0.02466750
# Iteration 256, loss = 0.02455513
# Iteration 257, loss = 0.02446567
# Iteration 258, loss = 0.02435481
# Iteration 259, loss = 0.02428184
# Iteration 260, loss = 0.02416687
# Iteration 261, loss = 0.02405823
# Iteration 262, loss = 0.02397622
# Iteration 263, loss = 0.02390799
# Iteration 264, loss = 0.02380655
# Iteration 265, loss = 0.02370061
# Iteration 266, loss = 0.02360413
# Iteration 267, loss = 0.02349875
# Iteration 268, loss = 0.02342862
# Iteration 269, loss = 0.02332590
# Iteration 270, loss = 0.02324214
# Iteration 271, loss = 0.02315268
# Iteration 272, loss = 0.02304891
# Iteration 273, loss = 0.02297735
# Iteration 274, loss = 0.02290066
# Iteration 275, loss = 0.02280417
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.72282970
# Iteration 2, loss = 0.71124615
# Iteration 3, loss = 0.69861955
# Iteration 4, loss = 0.69124309
# Iteration 5, loss = 0.68731202
# Iteration 6, loss = 0.68575460
# Iteration 7, loss = 0.68463783
# Iteration 8, loss = 0.68371078
# Iteration 9, loss = 0.68258325
# Iteration 10, loss = 0.68124869
# Iteration 11, loss = 0.67995626
# Iteration 12, loss = 0.67866946
# Iteration 13, loss = 0.67728958
# Iteration 14, loss = 0.67588790
# Iteration 15, loss = 0.67457630
# Iteration 16, loss = 0.67324529
# Iteration 17, loss = 0.67169911
# Iteration 18, loss = 0.67023359
# Iteration 19, loss = 0.66864212
# Iteration 20, loss = 0.66685798
# Iteration 21, loss = 0.66508500
# Iteration 22, loss = 0.66325287
# Iteration 23, loss = 0.66114210
# Iteration 24, loss = 0.65901371
# Iteration 25, loss = 0.65686958
# Iteration 26, loss = 0.65433778
# Iteration 27, loss = 0.65178300
# Iteration 28, loss = 0.64903802
# Iteration 29, loss = 0.64605805
# Iteration 30, loss = 0.64290583
# Iteration 31, loss = 0.63956905
# Iteration 32, loss = 0.63608220
# Iteration 33, loss = 0.63227072
# Iteration 34, loss = 0.62822950
# Iteration 35, loss = 0.62390768
# Iteration 36, loss = 0.61942335
# Iteration 37, loss = 0.61440579
# Iteration 38, loss = 0.60929424
# Iteration 39, loss = 0.60384539
# Iteration 40, loss = 0.59807348
# Iteration 41, loss = 0.59201696
# Iteration 42, loss = 0.58558033
# Iteration 43, loss = 0.57877841
# Iteration 44, loss = 0.57154027
# Iteration 45, loss = 0.56409366
# Iteration 46, loss = 0.55606401
# Iteration 47, loss = 0.54779106
# Iteration 48, loss = 0.53920777
# Iteration 49, loss = 0.53017027
# Iteration 50, loss = 0.52080981
# Iteration 51, loss = 0.51110979
# Iteration 52, loss = 0.50097232
# Iteration 53, loss = 0.49054240
# Iteration 54, loss = 0.47983539
# Iteration 55, loss = 0.46879588
# Iteration 56, loss = 0.45757494
# Iteration 57, loss = 0.44632261
# Iteration 58, loss = 0.43460711
# Iteration 59, loss = 0.42294676
# Iteration 60, loss = 0.41110865
# Iteration 61, loss = 0.39929062
# Iteration 62, loss = 0.38743114
# Iteration 63, loss = 0.37564803
# Iteration 64, loss = 0.36386700
# Iteration 65, loss = 0.35229388
# Iteration 66, loss = 0.34084487
# Iteration 67, loss = 0.32951614
# Iteration 68, loss = 0.31843955
# Iteration 69, loss = 0.30761129
# Iteration 70, loss = 0.29707243
# Iteration 71, loss = 0.28679172
# Iteration 72, loss = 0.27685895
# Iteration 73, loss = 0.26720201
# Iteration 74, loss = 0.25793626
# Iteration 75, loss = 0.24899700
# Iteration 76, loss = 0.24039362
# Iteration 77, loss = 0.23211626
# Iteration 78, loss = 0.22414436
# Iteration 79, loss = 0.21657417
# Iteration 80, loss = 0.20926332
# Iteration 81, loss = 0.20230184
# Iteration 82, loss = 0.19564074
# Iteration 83, loss = 0.18926699
# Iteration 84, loss = 0.18314119
# Iteration 85, loss = 0.17727532
# Iteration 86, loss = 0.17167879
# Iteration 87, loss = 0.16637014
# Iteration 88, loss = 0.16126425
# Iteration 89, loss = 0.15636010
# Iteration 90, loss = 0.15169656
# Iteration 91, loss = 0.14730114
# Iteration 92, loss = 0.14300143
# Iteration 93, loss = 0.13892584
# Iteration 94, loss = 0.13502476
# Iteration 95, loss = 0.13132364
# Iteration 96, loss = 0.12773123
# Iteration 97, loss = 0.12429799
# Iteration 98, loss = 0.12105952
# Iteration 99, loss = 0.11790674
# Iteration 100, loss = 0.11493448
# Iteration 101, loss = 0.11205463
# Iteration 102, loss = 0.10931199
# Iteration 103, loss = 0.10666474
# Iteration 104, loss = 0.10410978
# Iteration 105, loss = 0.10165341
# Iteration 106, loss = 0.09931628
# Iteration 107, loss = 0.09703243
# Iteration 108, loss = 0.09487109
# Iteration 109, loss = 0.09278599
# Iteration 110, loss = 0.09077908
# Iteration 111, loss = 0.08883446
# Iteration 112, loss = 0.08699944
# Iteration 113, loss = 0.08519966
# Iteration 114, loss = 0.08347690
# Iteration 115, loss = 0.08176625
# Iteration 116, loss = 0.08015771
# Iteration 117, loss = 0.07859535
# Iteration 118, loss = 0.07711288
# Iteration 119, loss = 0.07565396
# Iteration 120, loss = 0.07428015
# Iteration 121, loss = 0.07291063
# Iteration 122, loss = 0.07160109
# Iteration 123, loss = 0.07035254
# Iteration 124, loss = 0.06912863
# Iteration 125, loss = 0.06792972
# Iteration 126, loss = 0.06677644
# Iteration 127, loss = 0.06565092
# Iteration 128, loss = 0.06458960
# Iteration 129, loss = 0.06355353
# Iteration 130, loss = 0.06254783
# Iteration 131, loss = 0.06157453
# Iteration 132, loss = 0.06062956
# Iteration 133, loss = 0.05968386
# Iteration 134, loss = 0.05877483
# Iteration 135, loss = 0.05789178
# Iteration 136, loss = 0.05705985
# Iteration 137, loss = 0.05624677
# Iteration 138, loss = 0.05545763
# Iteration 139, loss = 0.05467970
# Iteration 140, loss = 0.05392076
# Iteration 141, loss = 0.05318282
# Iteration 142, loss = 0.05247250
# Iteration 143, loss = 0.05178427
# Iteration 144, loss = 0.05110235
# Iteration 145, loss = 0.05044987
# Iteration 146, loss = 0.04982085
# Iteration 147, loss = 0.04919886
# Iteration 148, loss = 0.04859791
# Iteration 149, loss = 0.04800951
# Iteration 150, loss = 0.04743886
# Iteration 151, loss = 0.04688564
# Iteration 152, loss = 0.04633223
# Iteration 153, loss = 0.04580594
# Iteration 154, loss = 0.04529649
# Iteration 155, loss = 0.04480163
# Iteration 156, loss = 0.04428709
# Iteration 157, loss = 0.04379992
# Iteration 158, loss = 0.04332766
# Iteration 159, loss = 0.04287123
# Iteration 160, loss = 0.04242491
# Iteration 161, loss = 0.04197277
# Iteration 162, loss = 0.04154569
# Iteration 163, loss = 0.04114055
# Iteration 164, loss = 0.04072222
# Iteration 165, loss = 0.04031898
# Iteration 166, loss = 0.03992776
# Iteration 167, loss = 0.03955111
# Iteration 168, loss = 0.03916472
# Iteration 169, loss = 0.03881498
# Iteration 170, loss = 0.03845289
# Iteration 171, loss = 0.03811012
# Iteration 172, loss = 0.03776350
# Iteration 173, loss = 0.03744432
# Iteration 174, loss = 0.03712634
# Iteration 175, loss = 0.03675017
# Iteration 176, loss = 0.03643544
# Iteration 177, loss = 0.03610887
# Iteration 178, loss = 0.03580563
# Iteration 179, loss = 0.03548868
# Iteration 180, loss = 0.03519064
# Iteration 181, loss = 0.03489717
# Iteration 182, loss = 0.03461435
# Iteration 183, loss = 0.03433070
# Iteration 184, loss = 0.03404634
# Iteration 185, loss = 0.03377852
# Iteration 186, loss = 0.03349863
# Iteration 187, loss = 0.03324198
# Iteration 188, loss = 0.03298204
# Iteration 189, loss = 0.03273020
# Iteration 190, loss = 0.03248582
# Iteration 191, loss = 0.03224693
# Iteration 192, loss = 0.03200308
# Iteration 193, loss = 0.03177362
# Iteration 194, loss = 0.03154941
# Iteration 195, loss = 0.03130682
# Iteration 196, loss = 0.03108452
# Iteration 197, loss = 0.03091060
# Iteration 198, loss = 0.03068819
# Iteration 199, loss = 0.03046002
# Iteration 200, loss = 0.03023754
# Iteration 201, loss = 0.03002819
# Iteration 202, loss = 0.02985501
# Iteration 203, loss = 0.02964615
# Iteration 204, loss = 0.02944001
# Iteration 205, loss = 0.02924714
# Iteration 206, loss = 0.02908353
# Iteration 207, loss = 0.02889733
# Iteration 208, loss = 0.02869872
# Iteration 209, loss = 0.02852516
# Iteration 210, loss = 0.02834706
# Iteration 211, loss = 0.02817425
# Iteration 212, loss = 0.02801339
# Iteration 213, loss = 0.02783332
# Iteration 214, loss = 0.02766656
# Iteration 215, loss = 0.02751199
# Iteration 216, loss = 0.02734153
# Iteration 217, loss = 0.02718256
# Iteration 218, loss = 0.02703663
# Iteration 219, loss = 0.02688009
# Iteration 220, loss = 0.02672996
# Iteration 221, loss = 0.02659562
# Iteration 222, loss = 0.02644611
# Iteration 223, loss = 0.02628221
# Iteration 224, loss = 0.02617025
# Iteration 225, loss = 0.02599901
# Iteration 226, loss = 0.02585035
# Iteration 227, loss = 0.02571686
# Iteration 228, loss = 0.02558200
# Iteration 229, loss = 0.02544251
# Iteration 230, loss = 0.02530381
# Iteration 231, loss = 0.02517333
# Iteration 232, loss = 0.02504203
# Iteration 233, loss = 0.02490922
# Iteration 234, loss = 0.02478374
# Iteration 235, loss = 0.02467960
# Iteration 236, loss = 0.02453231
# Iteration 237, loss = 0.02440675
# Iteration 238, loss = 0.02429243
# Iteration 239, loss = 0.02417088
# Iteration 240, loss = 0.02404851
# Iteration 241, loss = 0.02392587
# Iteration 242, loss = 0.02382413
# Iteration 243, loss = 0.02371050
# Iteration 244, loss = 0.02360310
# Iteration 245, loss = 0.02348029
# Iteration 246, loss = 0.02336019
# Iteration 247, loss = 0.02326129
# Iteration 248, loss = 0.02315818
# Iteration 249, loss = 0.02304455
# Iteration 250, loss = 0.02294880
# Iteration 251, loss = 0.02284760
# Iteration 252, loss = 0.02274677
# Iteration 253, loss = 0.02264999
# Iteration 254, loss = 0.02254325
# Iteration 255, loss = 0.02244720
# Iteration 256, loss = 0.02237203
# Iteration 257, loss = 0.02226387
# Iteration 258, loss = 0.02215033
# Iteration 259, loss = 0.02206429
# Iteration 260, loss = 0.02198562
# Iteration 261, loss = 0.02189832
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.68233817
# Iteration 2, loss = 0.68148162
# Iteration 3, loss = 0.68056825
# Iteration 4, loss = 0.67937040
# Iteration 5, loss = 0.67836689
# Iteration 6, loss = 0.67717910
# Iteration 7, loss = 0.67604695
# Iteration 8, loss = 0.67480696
# Iteration 9, loss = 0.67364709
# Iteration 10, loss = 0.67229605
# Iteration 11, loss = 0.67097650
# Iteration 12, loss = 0.66967206
# Iteration 13, loss = 0.66827959
# Iteration 14, loss = 0.66690057
# Iteration 15, loss = 0.66531846
# Iteration 16, loss = 0.66380340
# Iteration 17, loss = 0.66215202
# Iteration 18, loss = 0.66039436
# Iteration 19, loss = 0.65869795
# Iteration 20, loss = 0.65671343
# Iteration 21, loss = 0.65473291
# Iteration 22, loss = 0.65271598
# Iteration 23, loss = 0.65039060
# Iteration 24, loss = 0.64800575
# Iteration 25, loss = 0.64548162
# Iteration 26, loss = 0.64291501
# Iteration 27, loss = 0.63999401
# Iteration 28, loss = 0.63695660
# Iteration 29, loss = 0.63373705
# Iteration 30, loss = 0.63033531
# Iteration 31, loss = 0.62659149
# Iteration 32, loss = 0.62305628
# Iteration 33, loss = 0.61864233
# Iteration 34, loss = 0.61415236
# Iteration 35, loss = 0.60949981
# Iteration 36, loss = 0.60454051
# Iteration 37, loss = 0.59927595
# Iteration 38, loss = 0.59358573
# Iteration 39, loss = 0.58767359
# Iteration 40, loss = 0.58133491
# Iteration 41, loss = 0.57457857
# Iteration 42, loss = 0.56755305
# Iteration 43, loss = 0.56013899
# Iteration 44, loss = 0.55222410
# Iteration 45, loss = 0.54403167
# Iteration 46, loss = 0.53531340
# Iteration 47, loss = 0.52632117
# Iteration 48, loss = 0.51688913
# Iteration 49, loss = 0.50696335
# Iteration 50, loss = 0.49677924
# Iteration 51, loss = 0.48620151
# Iteration 52, loss = 0.47539512
# Iteration 53, loss = 0.46425426
# Iteration 54, loss = 0.45283804
# Iteration 55, loss = 0.44117947
# Iteration 56, loss = 0.42932870
# Iteration 57, loss = 0.41734384
# Iteration 58, loss = 0.40527615
# Iteration 59, loss = 0.39324042
# Iteration 60, loss = 0.38105480
# Iteration 61, loss = 0.36907376
# Iteration 62, loss = 0.35710639
# Iteration 63, loss = 0.34536093
# Iteration 64, loss = 0.33366887
# Iteration 65, loss = 0.32247756
# Iteration 66, loss = 0.31135440
# Iteration 67, loss = 0.30059252
# Iteration 68, loss = 0.29013881
# Iteration 69, loss = 0.28005597
# Iteration 70, loss = 0.27015606
# Iteration 71, loss = 0.26060340
# Iteration 72, loss = 0.25146559
# Iteration 73, loss = 0.24253270
# Iteration 74, loss = 0.23404924
# Iteration 75, loss = 0.22591029
# Iteration 76, loss = 0.21819191
# Iteration 77, loss = 0.21071903
# Iteration 78, loss = 0.20361934
# Iteration 79, loss = 0.19674592
# Iteration 80, loss = 0.19027105
# Iteration 81, loss = 0.18405530
# Iteration 82, loss = 0.17806063
# Iteration 83, loss = 0.17242804
# Iteration 84, loss = 0.16703441
# Iteration 85, loss = 0.16189755
# Iteration 86, loss = 0.15698611
# Iteration 87, loss = 0.15233477
# Iteration 88, loss = 0.14793219
# Iteration 89, loss = 0.14359603
# Iteration 90, loss = 0.13953905
# Iteration 91, loss = 0.13564594
# Iteration 92, loss = 0.13187592
# Iteration 93, loss = 0.12837395
# Iteration 94, loss = 0.12493794
# Iteration 95, loss = 0.12166140
# Iteration 96, loss = 0.11855500
# Iteration 97, loss = 0.11560263
# Iteration 98, loss = 0.11272802
# Iteration 99, loss = 0.10998274
# Iteration 100, loss = 0.10736660
# Iteration 101, loss = 0.10486289
# Iteration 102, loss = 0.10248793
# Iteration 103, loss = 0.10012519
# Iteration 104, loss = 0.09790448
# Iteration 105, loss = 0.09577485
# Iteration 106, loss = 0.09368585
# Iteration 107, loss = 0.09173426
# Iteration 108, loss = 0.08981202
# Iteration 109, loss = 0.08795173
# Iteration 110, loss = 0.08617326
# Iteration 111, loss = 0.08449728
# Iteration 112, loss = 0.08286462
# Iteration 113, loss = 0.08129076
# Iteration 114, loss = 0.07978168
# Iteration 115, loss = 0.07829324
# Iteration 116, loss = 0.07688682
# Iteration 117, loss = 0.07546801
# Iteration 118, loss = 0.07415844
# Iteration 119, loss = 0.07286643
# Iteration 120, loss = 0.07163821
# Iteration 121, loss = 0.07046552
# Iteration 122, loss = 0.06932521
# Iteration 123, loss = 0.06815928
# Iteration 124, loss = 0.06709214
# Iteration 125, loss = 0.06602329
# Iteration 126, loss = 0.06501736
# Iteration 127, loss = 0.06400974
# Iteration 128, loss = 0.06301557
# Iteration 129, loss = 0.06209084
# Iteration 130, loss = 0.06114639
# Iteration 131, loss = 0.06029471
# Iteration 132, loss = 0.05943588
# Iteration 133, loss = 0.05865323
# Iteration 134, loss = 0.05779947
# Iteration 135, loss = 0.05699657
# Iteration 136, loss = 0.05625269
# Iteration 137, loss = 0.05552124
# Iteration 138, loss = 0.05478280
# Iteration 139, loss = 0.05407776
# Iteration 140, loss = 0.05339734
# Iteration 141, loss = 0.05270883
# Iteration 142, loss = 0.05208146
# Iteration 143, loss = 0.05141738
# Iteration 144, loss = 0.05081652
# Iteration 145, loss = 0.05019195
# Iteration 146, loss = 0.04962583
# Iteration 147, loss = 0.04909115
# Iteration 148, loss = 0.04851571
# Iteration 149, loss = 0.04801614
# Iteration 150, loss = 0.04746596
# Iteration 151, loss = 0.04698632
# Iteration 152, loss = 0.04651474
# Iteration 153, loss = 0.04593250
# Iteration 154, loss = 0.04546074
# Iteration 155, loss = 0.04498475
# Iteration 156, loss = 0.04454852
# Iteration 157, loss = 0.04413112
# Iteration 158, loss = 0.04367259
# Iteration 159, loss = 0.04325781
# Iteration 160, loss = 0.04279407
# Iteration 161, loss = 0.04239334
# Iteration 162, loss = 0.04196072
# Iteration 163, loss = 0.04157772
# Iteration 164, loss = 0.04117378
# Iteration 165, loss = 0.04082423
# Iteration 166, loss = 0.04047421
# Iteration 167, loss = 0.04009943
# Iteration 168, loss = 0.03976057
# Iteration 169, loss = 0.03940196
# Iteration 170, loss = 0.03902942
# Iteration 171, loss = 0.03871160
# Iteration 172, loss = 0.03839776
# Iteration 173, loss = 0.03807047
# Iteration 174, loss = 0.03776378
# Iteration 175, loss = 0.03742859
# Iteration 176, loss = 0.03711772
# Iteration 177, loss = 0.03685250
# Iteration 178, loss = 0.03654338
# Iteration 179, loss = 0.03627009
# Iteration 180, loss = 0.03601711
# Iteration 181, loss = 0.03572469
# Iteration 182, loss = 0.03545438
# Iteration 183, loss = 0.03519035
# Iteration 184, loss = 0.03493256
# Iteration 185, loss = 0.03465581
# Iteration 186, loss = 0.03445180
# Iteration 187, loss = 0.03417315
# Iteration 188, loss = 0.03394276
# Iteration 189, loss = 0.03369034
# Iteration 190, loss = 0.03345131
# Iteration 191, loss = 0.03324304
# Iteration 192, loss = 0.03314752
# Iteration 193, loss = 0.03280887
# Iteration 194, loss = 0.03258668
# Iteration 195, loss = 0.03237421
# Iteration 196, loss = 0.03217116
# Iteration 197, loss = 0.03194165
# Iteration 198, loss = 0.03174632
# Iteration 199, loss = 0.03153914
# Iteration 200, loss = 0.03137864
# Iteration 201, loss = 0.03118754
# Iteration 202, loss = 0.03098685
# Iteration 203, loss = 0.03078554
# Iteration 204, loss = 0.03059776
# Iteration 205, loss = 0.03042676
# Iteration 206, loss = 0.03028107
# Iteration 207, loss = 0.03008528
# Iteration 208, loss = 0.02988339
# Iteration 209, loss = 0.02971597
# Iteration 210, loss = 0.02955513
# Iteration 211, loss = 0.02939151
# Iteration 212, loss = 0.02923906
# Iteration 213, loss = 0.02907309
# Iteration 214, loss = 0.02892408
# Iteration 215, loss = 0.02875834
# Iteration 216, loss = 0.02862196
# Iteration 217, loss = 0.02847053
# Iteration 218, loss = 0.02833005
# Iteration 219, loss = 0.02816045
# Iteration 220, loss = 0.02800840
# Iteration 221, loss = 0.02787728
# Iteration 222, loss = 0.02770326
# Iteration 223, loss = 0.02758464
# Iteration 224, loss = 0.02745574
# Iteration 225, loss = 0.02731825
# Iteration 226, loss = 0.02717906
# Iteration 227, loss = 0.02704675
# Iteration 228, loss = 0.02692377
# Iteration 229, loss = 0.02682473
# Iteration 230, loss = 0.02671569
# Iteration 231, loss = 0.02653281
# Iteration 232, loss = 0.02641990
# Iteration 233, loss = 0.02635158
# Iteration 234, loss = 0.02626421
# Iteration 235, loss = 0.02607560
# Iteration 236, loss = 0.02595053
# Iteration 237, loss = 0.02583137
# Iteration 238, loss = 0.02578860
# Iteration 239, loss = 0.02562361
# Iteration 240, loss = 0.02551420
# Iteration 241, loss = 0.02539111
# Iteration 242, loss = 0.02531095
# Iteration 243, loss = 0.02517875
# Iteration 244, loss = 0.02506864
# Iteration 245, loss = 0.02498272
# Iteration 246, loss = 0.02485362
# Iteration 247, loss = 0.02480489
# Iteration 248, loss = 0.02465840
# Iteration 249, loss = 0.02457668
# Iteration 250, loss = 0.02457912
# Iteration 251, loss = 0.02440129
# Iteration 252, loss = 0.02433577
# Iteration 253, loss = 0.02430164
# Iteration 254, loss = 0.02417228
# Iteration 255, loss = 0.02401762
# Iteration 256, loss = 0.02392702
# Iteration 257, loss = 0.02380498
# Iteration 258, loss = 0.02375925
# Iteration 259, loss = 0.02363978
# Iteration 260, loss = 0.02355870
# Iteration 261, loss = 0.02348015
# Iteration 262, loss = 0.02339193
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.67914423
# Iteration 2, loss = 0.67841454
# Iteration 3, loss = 0.67745224
# Iteration 4, loss = 0.67622481
# Iteration 5, loss = 0.67489347
# Iteration 6, loss = 0.67359440
# Iteration 7, loss = 0.67209329
# Iteration 8, loss = 0.67042039
# Iteration 9, loss = 0.66868511
# Iteration 10, loss = 0.66680352
# Iteration 11, loss = 0.66495628
# Iteration 12, loss = 0.66293566
# Iteration 13, loss = 0.66091636
# Iteration 14, loss = 0.65877446
# Iteration 15, loss = 0.65652143
# Iteration 16, loss = 0.65408147
# Iteration 17, loss = 0.65152022
# Iteration 18, loss = 0.64884061
# Iteration 19, loss = 0.64600772
# Iteration 20, loss = 0.64312065
# Iteration 21, loss = 0.63997830
# Iteration 22, loss = 0.63666429
# Iteration 23, loss = 0.63319925
# Iteration 24, loss = 0.62953778
# Iteration 25, loss = 0.62557102
# Iteration 26, loss = 0.62139788
# Iteration 27, loss = 0.61698537
# Iteration 28, loss = 0.61233653
# Iteration 29, loss = 0.60746777
# Iteration 30, loss = 0.60217849
# Iteration 31, loss = 0.59665770
# Iteration 32, loss = 0.59083712
# Iteration 33, loss = 0.58463464
# Iteration 34, loss = 0.57808900
# Iteration 35, loss = 0.57117054
# Iteration 36, loss = 0.56378561
# Iteration 37, loss = 0.55619104
# Iteration 38, loss = 0.54810955
# Iteration 39, loss = 0.53976281
# Iteration 40, loss = 0.53070520
# Iteration 41, loss = 0.52138941
# Iteration 42, loss = 0.51172467
# Iteration 43, loss = 0.50169221
# Iteration 44, loss = 0.49120470
# Iteration 45, loss = 0.48036459
# Iteration 46, loss = 0.46941941
# Iteration 47, loss = 0.45784644
# Iteration 48, loss = 0.44617198
# Iteration 49, loss = 0.43425576
# Iteration 50, loss = 0.42218732
# Iteration 51, loss = 0.40997014
# Iteration 52, loss = 0.39771204
# Iteration 53, loss = 0.38548482
# Iteration 54, loss = 0.37307025
# Iteration 55, loss = 0.36089181
# Iteration 56, loss = 0.34871064
# Iteration 57, loss = 0.33674447
# Iteration 58, loss = 0.32498103
# Iteration 59, loss = 0.31350260
# Iteration 60, loss = 0.30233844
# Iteration 61, loss = 0.29147496
# Iteration 62, loss = 0.28100725
# Iteration 63, loss = 0.27080590
# Iteration 64, loss = 0.26102574
# Iteration 65, loss = 0.25155680
# Iteration 66, loss = 0.24248187
# Iteration 67, loss = 0.23386318
# Iteration 68, loss = 0.22555913
# Iteration 69, loss = 0.21762908
# Iteration 70, loss = 0.21005155
# Iteration 71, loss = 0.20284392
# Iteration 72, loss = 0.19600648
# Iteration 73, loss = 0.18943382
# Iteration 74, loss = 0.18318334
# Iteration 75, loss = 0.17720803
# Iteration 76, loss = 0.17152279
# Iteration 77, loss = 0.16608706
# Iteration 78, loss = 0.16091138
# Iteration 79, loss = 0.15599309
# Iteration 80, loss = 0.15124232
# Iteration 81, loss = 0.14678047
# Iteration 82, loss = 0.14251012
# Iteration 83, loss = 0.13842670
# Iteration 84, loss = 0.13453583
# Iteration 85, loss = 0.13084554
# Iteration 86, loss = 0.12729160
# Iteration 87, loss = 0.12393168
# Iteration 88, loss = 0.12065044
# Iteration 89, loss = 0.11757836
# Iteration 90, loss = 0.11460723
# Iteration 91, loss = 0.11175196
# Iteration 92, loss = 0.10906290
# Iteration 93, loss = 0.10646303
# Iteration 94, loss = 0.10397537
# Iteration 95, loss = 0.10155673
# Iteration 96, loss = 0.09924122
# Iteration 97, loss = 0.09703651
# Iteration 98, loss = 0.09490699
# Iteration 99, loss = 0.09290158
# Iteration 100, loss = 0.09094390
# Iteration 101, loss = 0.08910475
# Iteration 102, loss = 0.08721103
# Iteration 103, loss = 0.08547395
# Iteration 104, loss = 0.08379127
# Iteration 105, loss = 0.08218201
# Iteration 106, loss = 0.08062023
# Iteration 107, loss = 0.07914469
# Iteration 108, loss = 0.07767277
# Iteration 109, loss = 0.07628093
# Iteration 110, loss = 0.07494229
# Iteration 111, loss = 0.07365241
# Iteration 112, loss = 0.07242005
# Iteration 113, loss = 0.07122167
# Iteration 114, loss = 0.07003305
# Iteration 115, loss = 0.06890096
# Iteration 116, loss = 0.06780543
# Iteration 117, loss = 0.06676220
# Iteration 118, loss = 0.06569004
# Iteration 119, loss = 0.06466790
# Iteration 120, loss = 0.06369869
# Iteration 121, loss = 0.06278089
# Iteration 122, loss = 0.06186752
# Iteration 123, loss = 0.06095170
# Iteration 124, loss = 0.06006626
# Iteration 125, loss = 0.05922249
# Iteration 126, loss = 0.05841080
# Iteration 127, loss = 0.05760514
# Iteration 128, loss = 0.05684336
# Iteration 129, loss = 0.05609377
# Iteration 130, loss = 0.05537031
# Iteration 131, loss = 0.05466183
# Iteration 132, loss = 0.05397991
# Iteration 133, loss = 0.05329788
# Iteration 134, loss = 0.05266044
# Iteration 135, loss = 0.05210468
# Iteration 136, loss = 0.05141185
# Iteration 137, loss = 0.05080660
# Iteration 138, loss = 0.05021623
# Iteration 139, loss = 0.04964351
# Iteration 140, loss = 0.04909499
# Iteration 141, loss = 0.04854618
# Iteration 142, loss = 0.04802582
# Iteration 143, loss = 0.04752630
# Iteration 144, loss = 0.04708035
# Iteration 145, loss = 0.04652275
# Iteration 146, loss = 0.04607759
# Iteration 147, loss = 0.04556079
# Iteration 148, loss = 0.04510548
# Iteration 149, loss = 0.04465111
# Iteration 150, loss = 0.04419510
# Iteration 151, loss = 0.04378486
# Iteration 152, loss = 0.04338729
# Iteration 153, loss = 0.04298809
# Iteration 154, loss = 0.04255659
# Iteration 155, loss = 0.04216704
# Iteration 156, loss = 0.04178244
# Iteration 157, loss = 0.04140569
# Iteration 158, loss = 0.04103580
# Iteration 159, loss = 0.04070978
# Iteration 160, loss = 0.04034309
# Iteration 161, loss = 0.04001364
# Iteration 162, loss = 0.03966955
# Iteration 163, loss = 0.03933864
# Iteration 164, loss = 0.03903447
# Iteration 165, loss = 0.03872735
# Iteration 166, loss = 0.03839684
# Iteration 167, loss = 0.03809946
# Iteration 168, loss = 0.03778814
# Iteration 169, loss = 0.03749901
# Iteration 170, loss = 0.03722164
# Iteration 171, loss = 0.03692757
# Iteration 172, loss = 0.03668320
# Iteration 173, loss = 0.03641779
# Iteration 174, loss = 0.03613417
# Iteration 175, loss = 0.03586187
# Iteration 176, loss = 0.03560379
# Iteration 177, loss = 0.03535619
# Iteration 178, loss = 0.03513492
# Iteration 179, loss = 0.03485668
# Iteration 180, loss = 0.03462953
# Iteration 181, loss = 0.03439960
# Iteration 182, loss = 0.03418675
# Iteration 183, loss = 0.03396137
# Iteration 184, loss = 0.03370406
# Iteration 185, loss = 0.03351142
# Iteration 186, loss = 0.03327793
# Iteration 187, loss = 0.03309759
# Iteration 188, loss = 0.03287404
# Iteration 189, loss = 0.03264579
# Iteration 190, loss = 0.03243651
# Iteration 191, loss = 0.03225546
# Iteration 192, loss = 0.03204531
# Iteration 193, loss = 0.03188765
# Iteration 194, loss = 0.03164831
# Iteration 195, loss = 0.03148730
# Iteration 196, loss = 0.03131427
# Iteration 197, loss = 0.03115790
# Iteration 198, loss = 0.03095247
# Iteration 199, loss = 0.03074446
# Iteration 200, loss = 0.03057365
# Iteration 201, loss = 0.03040586
# Iteration 202, loss = 0.03024571
# Iteration 203, loss = 0.03018246
# Iteration 204, loss = 0.02991835
# Iteration 205, loss = 0.02971940
# Iteration 206, loss = 0.02956520
# Iteration 207, loss = 0.02943326
# Iteration 208, loss = 0.02929591
# Iteration 209, loss = 0.02912950
# Iteration 210, loss = 0.02897990
# Iteration 211, loss = 0.02885240
# Iteration 212, loss = 0.02867929
# Iteration 213, loss = 0.02854498
# Iteration 214, loss = 0.02844354
# Iteration 215, loss = 0.02829487
# Iteration 216, loss = 0.02813205
# Iteration 217, loss = 0.02803665
# Iteration 218, loss = 0.02788549
# Iteration 219, loss = 0.02776410
# Iteration 220, loss = 0.02762862
# Iteration 221, loss = 0.02752799
# Iteration 222, loss = 0.02737496
# Iteration 223, loss = 0.02725729
# Iteration 224, loss = 0.02710017
# Iteration 225, loss = 0.02700923
# Iteration 226, loss = 0.02697317
# Iteration 227, loss = 0.02682971
# Iteration 228, loss = 0.02665540
# Iteration 229, loss = 0.02652939
# Iteration 230, loss = 0.02643718
# Iteration 231, loss = 0.02635878
# Iteration 232, loss = 0.02619238
# Iteration 233, loss = 0.02610218
# Iteration 234, loss = 0.02597966
# Iteration 235, loss = 0.02592883
# Iteration 236, loss = 0.02581063
# Iteration 237, loss = 0.02570300
# Iteration 238, loss = 0.02553652
# Iteration 239, loss = 0.02547068
# Iteration 240, loss = 0.02539196
# Iteration 241, loss = 0.02529027
# Iteration 242, loss = 0.02517845
# Iteration 243, loss = 0.02507687
# Iteration 244, loss = 0.02504375
# Iteration 245, loss = 0.02493347
# Iteration 246, loss = 0.02476115
# Iteration 247, loss = 0.02470560
# Iteration 248, loss = 0.02463225
# Iteration 249, loss = 0.02455122
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.68597788
# Iteration 2, loss = 0.68532088
# Iteration 3, loss = 0.68409701
# Iteration 4, loss = 0.68300631
# Iteration 5, loss = 0.68191004
# Iteration 6, loss = 0.68058071
# Iteration 7, loss = 0.67943868
# Iteration 8, loss = 0.67812419
# Iteration 9, loss = 0.67686624
# Iteration 10, loss = 0.67558215
# Iteration 11, loss = 0.67421158
# Iteration 12, loss = 0.67274475
# Iteration 13, loss = 0.67137140
# Iteration 14, loss = 0.66988386
# Iteration 15, loss = 0.66842024
# Iteration 16, loss = 0.66676391
# Iteration 17, loss = 0.66517187
# Iteration 18, loss = 0.66341405
# Iteration 19, loss = 0.66160863
# Iteration 20, loss = 0.65973061
# Iteration 21, loss = 0.65783668
# Iteration 22, loss = 0.65573429
# Iteration 23, loss = 0.65363655
# Iteration 24, loss = 0.65133477
# Iteration 25, loss = 0.64900008
# Iteration 26, loss = 0.64657765
# Iteration 27, loss = 0.64409016
# Iteration 28, loss = 0.64130410
# Iteration 29, loss = 0.63850400
# Iteration 30, loss = 0.63562143
# Iteration 31, loss = 0.63254919
# Iteration 32, loss = 0.62926664
# Iteration 33, loss = 0.62578610
# Iteration 34, loss = 0.62220584
# Iteration 35, loss = 0.61840076
# Iteration 36, loss = 0.61445450
# Iteration 37, loss = 0.61022624
# Iteration 38, loss = 0.60587915
# Iteration 39, loss = 0.60122193
# Iteration 40, loss = 0.59647040
# Iteration 41, loss = 0.59137567
# Iteration 42, loss = 0.58606399
# Iteration 43, loss = 0.58056124
# Iteration 44, loss = 0.57475130
# Iteration 45, loss = 0.56877415
# Iteration 46, loss = 0.56238685
# Iteration 47, loss = 0.55583281
# Iteration 48, loss = 0.54899638
# Iteration 49, loss = 0.54194566
# Iteration 50, loss = 0.53461217
# Iteration 51, loss = 0.52704344
# Iteration 52, loss = 0.51934472
# Iteration 53, loss = 0.51123873
# Iteration 54, loss = 0.50311216
# Iteration 55, loss = 0.49467666
# Iteration 56, loss = 0.48610402
# Iteration 57, loss = 0.47729227
# Iteration 58, loss = 0.46829842
# Iteration 59, loss = 0.45917617
# Iteration 60, loss = 0.45003432
# Iteration 61, loss = 0.44068758
# Iteration 62, loss = 0.43135934
# Iteration 63, loss = 0.42189533
# Iteration 64, loss = 0.41245935
# Iteration 65, loss = 0.40309745
# Iteration 66, loss = 0.39365007
# Iteration 67, loss = 0.38431357
# Iteration 68, loss = 0.37502562
# Iteration 69, loss = 0.36579804
# Iteration 70, loss = 0.35664128
# Iteration 71, loss = 0.34760855
# Iteration 72, loss = 0.33865968
# Iteration 73, loss = 0.32990145
# Iteration 74, loss = 0.32130675
# Iteration 75, loss = 0.31277659
# Iteration 76, loss = 0.30446081
# Iteration 77, loss = 0.29634228
# Iteration 78, loss = 0.28844711
# Iteration 79, loss = 0.28069029
# Iteration 80, loss = 0.27320210
# Iteration 81, loss = 0.26580719
# Iteration 82, loss = 0.25868774
# Iteration 83, loss = 0.25187158
# Iteration 84, loss = 0.24519132
# Iteration 85, loss = 0.23862686
# Iteration 86, loss = 0.23237068
# Iteration 87, loss = 0.22618338
# Iteration 88, loss = 0.22019537
# Iteration 89, loss = 0.21443872
# Iteration 90, loss = 0.20885128
# Iteration 91, loss = 0.20337356
# Iteration 92, loss = 0.19815485
# Iteration 93, loss = 0.19310950
# Iteration 94, loss = 0.18815826
# Iteration 95, loss = 0.18349518
# Iteration 96, loss = 0.17889877
# Iteration 97, loss = 0.17448965
# Iteration 98, loss = 0.17026939
# Iteration 99, loss = 0.16613223
# Iteration 100, loss = 0.16216948
# Iteration 101, loss = 0.15827613
# Iteration 102, loss = 0.15455593
# Iteration 103, loss = 0.15098160
# Iteration 104, loss = 0.14751233
# Iteration 105, loss = 0.14415286
# Iteration 106, loss = 0.14092596
# Iteration 107, loss = 0.13781225
# Iteration 108, loss = 0.13478621
# Iteration 109, loss = 0.13179875
# Iteration 110, loss = 0.12893567
# Iteration 111, loss = 0.12625812
# Iteration 112, loss = 0.12354492
# Iteration 113, loss = 0.12102970
# Iteration 114, loss = 0.11857885
# Iteration 115, loss = 0.11613126
# Iteration 116, loss = 0.11377065
# Iteration 117, loss = 0.11152482
# Iteration 118, loss = 0.10939149
# Iteration 119, loss = 0.10722902
# Iteration 120, loss = 0.10516151
# Iteration 121, loss = 0.10315262
# Iteration 122, loss = 0.10126378
# Iteration 123, loss = 0.09938407
# Iteration 124, loss = 0.09753134
# Iteration 125, loss = 0.09576827
# Iteration 126, loss = 0.09406250
# Iteration 127, loss = 0.09242143
# Iteration 128, loss = 0.09079281
# Iteration 129, loss = 0.08925634
# Iteration 130, loss = 0.08773848
# Iteration 131, loss = 0.08629158
# Iteration 132, loss = 0.08483530
# Iteration 133, loss = 0.08353194
# Iteration 134, loss = 0.08214047
# Iteration 135, loss = 0.08081274
# Iteration 136, loss = 0.07955141
# Iteration 137, loss = 0.07833961
# Iteration 138, loss = 0.07713392
# Iteration 139, loss = 0.07598814
# Iteration 140, loss = 0.07480443
# Iteration 141, loss = 0.07370641
# Iteration 142, loss = 0.07265272
# Iteration 143, loss = 0.07163108
# Iteration 144, loss = 0.07057808
# Iteration 145, loss = 0.06959961
# Iteration 146, loss = 0.06866736
# ...
# Iteration 35, loss = 0.60984847
# Iteration 36, loss = 0.60495490
# Iteration 37, loss = 0.59990562
# Iteration 38, loss = 0.59448345
# Iteration 39, loss = 0.58868136
# Iteration 40, loss = 0.58270284
# Iteration 41, loss = 0.57619177
# Iteration 42, loss = 0.56949231
# Iteration 43, loss = 0.56235364
# Iteration 44, loss = 0.55494006
# Iteration 45, loss = 0.54711632
# Iteration 46, loss = 0.53905624
# Iteration 47, loss = 0.53057182
# Iteration 48, loss = 0.52188789
# Iteration 49, loss = 0.51270764
# Iteration 50, loss = 0.50336730
# Iteration 51, loss = 0.49375905
# Iteration 52, loss = 0.48374111
# Iteration 53, loss = 0.47361325
# Iteration 54, loss = 0.46321892
# Iteration 55, loss = 0.45273537
# Iteration 56, loss = 0.44197364
# Iteration 57, loss = 0.43118946
# Iteration 58, loss = 0.42021673
# Iteration 59, loss = 0.40945525
# Iteration 60, loss = 0.39860965
# Iteration 61, loss = 0.38765634
# Iteration 62, loss = 0.37664943
# Iteration 63, loss = 0.36590099
# Iteration 64, loss = 0.35515419
# Iteration 65, loss = 0.34471731
# Iteration 66, loss = 0.33436019
# Iteration 67, loss = 0.32431722
# Iteration 68, loss = 0.31437248
# Iteration 69, loss = 0.30471431
# Iteration 70, loss = 0.29527162
# Iteration 71, loss = 0.28612520
# Iteration 72, loss = 0.27724374
# Iteration 73, loss = 0.26855993
# Iteration 74, loss = 0.26019982
# Iteration 75, loss = 0.25215431
# Iteration 76, loss = 0.24435351
# Iteration 77, loss = 0.23686989
# Iteration 78, loss = 0.22962830
# Iteration 79, loss = 0.22263294
# Iteration 80, loss = 0.21593980
# Iteration 81, loss = 0.20939140
# Iteration 82, loss = 0.20313069
# Iteration 83, loss = 0.19714252
# Iteration 84, loss = 0.19135881
# Iteration 85, loss = 0.18584492
# Iteration 86, loss = 0.18044493
# Iteration 87, loss = 0.17532154
# Iteration 88, loss = 0.17041576
# Iteration 89, loss = 0.16570820
# Iteration 90, loss = 0.16113897
# Iteration 91, loss = 0.15680026
# Iteration 92, loss = 0.15262124
# Iteration 93, loss = 0.14860827
# Iteration 94, loss = 0.14476998
# Iteration 95, loss = 0.14100957
# Iteration 96, loss = 0.13743993
# Iteration 97, loss = 0.13397418
# Iteration 98, loss = 0.13066493
# Iteration 99, loss = 0.12744611
# Iteration 100, loss = 0.12441494
# Iteration 101, loss = 0.12143797
# Iteration 102, loss = 0.11861763
# Iteration 103, loss = 0.11589237
# Iteration 104, loss = 0.11321304
# Iteration 105, loss = 0.11071483
# Iteration 106, loss = 0.10827405
# Iteration 107, loss = 0.10590941
# Iteration 108, loss = 0.10371595
# Iteration 109, loss = 0.10148758
# Iteration 110, loss = 0.09931984
# Iteration 111, loss = 0.09733556
# Iteration 112, loss = 0.09537856
# Iteration 113, loss = 0.09350072
# Iteration 114, loss = 0.09162754
# Iteration 115, loss = 0.08984358
# Iteration 116, loss = 0.08815464
# Iteration 117, loss = 0.08650447
# Iteration 118, loss = 0.08494213
# Iteration 119, loss = 0.08336772
# Iteration 120, loss = 0.08186576
# Iteration 121, loss = 0.08041918
# Iteration 122, loss = 0.07903460
# Iteration 123, loss = 0.07767956
# Iteration 124, loss = 0.07639050
# Iteration 125, loss = 0.07510841
# Iteration 126, loss = 0.07386686
# Iteration 127, loss = 0.07271842
# Iteration 128, loss = 0.07153843
# Iteration 129, loss = 0.07042060
# Iteration 130, loss = 0.06935289
# Iteration 131, loss = 0.06831612
# Iteration 132, loss = 0.06731109
# Iteration 133, loss = 0.06631371
# Iteration 134, loss = 0.06536780
# Iteration 135, loss = 0.06445232
# Iteration 136, loss = 0.06353841
# Iteration 137, loss = 0.06269244
# Iteration 138, loss = 0.06182401
# Iteration 139, loss = 0.06100383
# Iteration 140, loss = 0.06021493
# Iteration 141, loss = 0.05943221
# Iteration 142, loss = 0.05867144
# Iteration 143, loss = 0.05793663
# Iteration 144, loss = 0.05720026
# Iteration 145, loss = 0.05654184
# Iteration 146, loss = 0.05585236
# Iteration 147, loss = 0.05515993
# Iteration 148, loss = 0.05455455
# Iteration 149, loss = 0.05398168
# Iteration 150, loss = 0.05332258
# Iteration 151, loss = 0.05270675
# Iteration 152, loss = 0.05211541
# Iteration 153, loss = 0.05154546
# Iteration 154, loss = 0.05098545
# Iteration 155, loss = 0.05044073
# Iteration 156, loss = 0.04998009
# Iteration 157, loss = 0.04941156
# Iteration 158, loss = 0.04891865
# Iteration 159, loss = 0.04840271
# Iteration 160, loss = 0.04796093
# Iteration 161, loss = 0.04747780
# Iteration 162, loss = 0.04701785
# Iteration 163, loss = 0.04656505
# Iteration 164, loss = 0.04611434
# Iteration 165, loss = 0.04567997
# Iteration 166, loss = 0.04526268
# Iteration 167, loss = 0.04485029
# Iteration 168, loss = 0.04445222
# Iteration 169, loss = 0.04405824
# Iteration 170, loss = 0.04366820
# Iteration 171, loss = 0.04329240
# Iteration 172, loss = 0.04290492
# Iteration 173, loss = 0.04258856
# Iteration 174, loss = 0.04222113
# Iteration 175, loss = 0.04192217
# Iteration 176, loss = 0.04151944
# Iteration 177, loss = 0.04117854
# Iteration 178, loss = 0.04086190
# Iteration 179, loss = 0.04053471
# Iteration 180, loss = 0.04022454
# Iteration 181, loss = 0.03988731
# Iteration 182, loss = 0.03960394
# Iteration 183, loss = 0.03932466
# Iteration 184, loss = 0.03900669
# Iteration 185, loss = 0.03874582
# Iteration 186, loss = 0.03845105
# Iteration 187, loss = 0.03815459
# Iteration 188, loss = 0.03789221
# Iteration 189, loss = 0.03763495
# Iteration 190, loss = 0.03735102
# Iteration 191, loss = 0.03708167
# Iteration 192, loss = 0.03682459
# Iteration 193, loss = 0.03657517
# Iteration 194, loss = 0.03633833
# Iteration 195, loss = 0.03613278
# Iteration 196, loss = 0.03588606
# Iteration 197, loss = 0.03563159
# Iteration 198, loss = 0.03541267
# Iteration 199, loss = 0.03520491
# Iteration 200, loss = 0.03499135
# Iteration 201, loss = 0.03478481
# Iteration 202, loss = 0.03453826
# Iteration 203, loss = 0.03433690
# Iteration 204, loss = 0.03411750
# Iteration 205, loss = 0.03391219
# Iteration 206, loss = 0.03374453
# Iteration 207, loss = 0.03353178
# Iteration 208, loss = 0.03332954
# Iteration 209, loss = 0.03313988
# Iteration 210, loss = 0.03296161
# Iteration 211, loss = 0.03279598
# Iteration 212, loss = 0.03260333
# Iteration 213, loss = 0.03242038
# Iteration 214, loss = 0.03222064
# Iteration 215, loss = 0.03205721
# Iteration 216, loss = 0.03187193
# Iteration 217, loss = 0.03170577
# Iteration 218, loss = 0.03156286
# Iteration 219, loss = 0.03137123
# Iteration 220, loss = 0.03120880
# Iteration 221, loss = 0.03106247
# Iteration 222, loss = 0.03095037
# Iteration 223, loss = 0.03073057
# Iteration 224, loss = 0.03061364
# Iteration 225, loss = 0.03045777
# Iteration 226, loss = 0.03032650
# Iteration 227, loss = 0.03016689
# Iteration 228, loss = 0.03004005
# Iteration 229, loss = 0.02989285
# Iteration 230, loss = 0.02976680
# Iteration 231, loss = 0.02969001
# Iteration 232, loss = 0.02947194
# Iteration 233, loss = 0.02933308
# Iteration 234, loss = 0.02920723
# Iteration 235, loss = 0.02913376
# Iteration 236, loss = 0.02891658
# Iteration 237, loss = 0.02879031
# Iteration 238, loss = 0.02866640
# Iteration 239, loss = 0.02853592
# Iteration 240, loss = 0.02843375
# Iteration 241, loss = 0.02828880
# Iteration 242, loss = 0.02815483
# Iteration 243, loss = 0.02804168
# Iteration 244, loss = 0.02792430
# Iteration 245, loss = 0.02778969
# Iteration 246, loss = 0.02771172
# Iteration 247, loss = 0.02755729
# Iteration 248, loss = 0.02742908
# Iteration 249, loss = 0.02733075
# Iteration 250, loss = 0.02722589
# Iteration 251, loss = 0.02712443
# Iteration 252, loss = 0.02699969
# Iteration 253, loss = 0.02699848
# Iteration 254, loss = 0.02679197
# Iteration 255, loss = 0.02668164
# Iteration 256, loss = 0.02660869
# Iteration 257, loss = 0.02648474
# Iteration 258, loss = 0.02637913
# Iteration 259, loss = 0.02624679
# Iteration 260, loss = 0.02613602
# Iteration 261, loss = 0.02602962
# Iteration 262, loss = 0.02594890
# Iteration 263, loss = 0.02583988
# Iteration 264, loss = 0.02576209
# Iteration 265, loss = 0.02563629
# Iteration 266, loss = 0.02554651
# Iteration 267, loss = 0.02543575
# Iteration 268, loss = 0.02534111
# Iteration 269, loss = 0.02524016
# Iteration 270, loss = 0.02515080
# Iteration 271, loss = 0.02506313
# Iteration 272, loss = 0.02493981
# Iteration 273, loss = 0.02486169
# Iteration 274, loss = 0.02478436
# Iteration 275, loss = 0.02471721
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
# Iteration 1, loss = 0.73018988
# Iteration 2, loss = 0.71292896
# Iteration 3, loss = 0.69638228
# Iteration 4, loss = 0.68489327
# Iteration 5, loss = 0.68059855
# Iteration 6, loss = 0.67761358
# Iteration 7, loss = 0.67666738
# Iteration 8, loss = 0.67552001
# Iteration 9, loss = 0.67416153
# Iteration 10, loss = 0.67267293
# Iteration 11, loss = 0.67091056
# Iteration 12, loss = 0.66904702
# Iteration 13, loss = 0.66730154
# Iteration 14, loss = 0.66549340
# Iteration 15, loss = 0.66353395
# Iteration 16, loss = 0.66147448
# Iteration 17, loss = 0.65941574
# Iteration 18, loss = 0.65709465
# Iteration 19, loss = 0.65476678
# Iteration 20, loss = 0.65205729
# Iteration 21, loss = 0.64944357
# Iteration 22, loss = 0.64640311
# Iteration 23, loss = 0.64320101
# Iteration 24, loss = 0.63984589
# Iteration 25, loss = 0.63630364
# Iteration 26, loss = 0.63243195
# Iteration 27, loss = 0.62839143
# Iteration 28, loss = 0.62406705
# Iteration 29, loss = 0.61922193
# Iteration 30, loss = 0.61429703
# Iteration 31, loss = 0.60902983
# Iteration 32, loss = 0.60344113
# Iteration 33, loss = 0.59751432
# Iteration 34, loss = 0.59132981
# Iteration 35, loss = 0.58479264
# Iteration 36, loss = 0.57811633
# Iteration 37, loss = 0.57101566
# Iteration 38, loss = 0.56351882
# Iteration 39, loss = 0.55563401
# Iteration 40, loss = 0.54754362
# Iteration 41, loss = 0.53900146
# Iteration 42, loss = 0.53011375
# Iteration 43, loss = 0.52098244
# Iteration 44, loss = 0.51123941
# Iteration 45, loss = 0.50125084
# Iteration 46, loss = 0.49081748
# Iteration 47, loss = 0.48009037
# Iteration 48, loss = 0.46905208
# Iteration 49, loss = 0.45768390
# Iteration 50, loss = 0.44620328
# Iteration 51, loss = 0.43433311
# Iteration 52, loss = 0.42235125
# Iteration 53, loss = 0.41024466
# Iteration 54, loss = 0.39794809
# Iteration 55, loss = 0.38572073
# Iteration 56, loss = 0.37347077
# Iteration 57, loss = 0.36125652
# Iteration 58, loss = 0.34913122
# Iteration 59, loss = 0.33725394
# Iteration 60, loss = 0.32547203
# Iteration 61, loss = 0.31388904
# Iteration 62, loss = 0.30273089
# Iteration 63, loss = 0.29163452
# Iteration 64, loss = 0.28099372
# Iteration 65, loss = 0.27063446
# Iteration 66, loss = 0.26063988
# Iteration 67, loss = 0.25095880
# Iteration 68, loss = 0.24167312
# Iteration 69, loss = 0.23275228
# Iteration 70, loss = 0.22428194
# Iteration 71, loss = 0.21605507
# Iteration 72, loss = 0.20825384
# Iteration 73, loss = 0.20080157
# Iteration 74, loss = 0.19365881
# Iteration 75, loss = 0.18692398
# Iteration 76, loss = 0.18038020
# Iteration 77, loss = 0.17418828
# Iteration 78, loss = 0.16834017
# Iteration 79, loss = 0.16271443
# Iteration 80, loss = 0.15741984
# Iteration 81, loss = 0.15237793
# Iteration 82, loss = 0.14749963
# Iteration 83, loss = 0.14287493
# Iteration 84, loss = 0.13846948
# Iteration 85, loss = 0.13433146
# Iteration 86, loss = 0.13034610
# Iteration 87, loss = 0.12657142
# Iteration 88, loss = 0.12295281
# Iteration 89, loss = 0.11953226
# Iteration 90, loss = 0.11626879
# Iteration 91, loss = 0.11313725
# Iteration 92, loss = 0.11011499
# Iteration 93, loss = 0.10727926
# Iteration 94, loss = 0.10449064
# Iteration 95, loss = 0.10189861
# Iteration 96, loss = 0.09934979
# Iteration 97, loss = 0.09700131
# Iteration 98, loss = 0.09467535
# Iteration 99, loss = 0.09247706
# Iteration 100, loss = 0.09036183
# Iteration 101, loss = 0.08835021
# Iteration 102, loss = 0.08640398
# Iteration 103, loss = 0.08449957
# Iteration 104, loss = 0.08273545
# Iteration 105, loss = 0.08098379
# Iteration 106, loss = 0.07934418
# Iteration 107, loss = 0.07770798
# Iteration 108, loss = 0.07617413
# Iteration 109, loss = 0.07469742
# Iteration 110, loss = 0.07325879
# Iteration 111, loss = 0.07186946
# Iteration 112, loss = 0.07054069
# Iteration 113, loss = 0.06926066
# Iteration 114, loss = 0.06802340
# Iteration 115, loss = 0.06684309
# Iteration 116, loss = 0.06565204
# Iteration 117, loss = 0.06453351
# Iteration 118, loss = 0.06345020
# Iteration 119, loss = 0.06240077
# Iteration 120, loss = 0.06138013
# Iteration 121, loss = 0.06039752
# Iteration 122, loss = 0.05945114
# Iteration 123, loss = 0.05854335
# Iteration 124, loss = 0.05765317
# Iteration 125, loss = 0.05679845
# Iteration 126, loss = 0.05594000
# Iteration 127, loss = 0.05512187
# Iteration 128, loss = 0.05434373
# Iteration 129, loss = 0.05359702
# Iteration 130, loss = 0.05282364
# Iteration 131, loss = 0.05209016
# Iteration 132, loss = 0.05140890
# Iteration 133, loss = 0.05070160
# Iteration 134, loss = 0.05004790
# Iteration 135, loss = 0.04939612
# Iteration 136, loss = 0.04878758
# Iteration 137, loss = 0.04817433
# Iteration 138, loss = 0.04758200
# Iteration 139, loss = 0.04701931
# Iteration 140, loss = 0.04647910
# Iteration 141, loss = 0.04593464
# Iteration 142, loss = 0.04539333
# Iteration 143, loss = 0.04486633
# Iteration 144, loss = 0.04434747
# Iteration 145, loss = 0.04383608
# Iteration 146, loss = 0.04334332
# Iteration 147, loss = 0.04286265
# Iteration 148, loss = 0.04241334
# Iteration 149, loss = 0.04195775
# Iteration 150, loss = 0.04150678
# Iteration 151, loss = 0.04107645
# Iteration 152, loss = 0.04066629
# Iteration 153, loss = 0.04025126
# Iteration 154, loss = 0.03985851
# Iteration 155, loss = 0.03943535
# Iteration 156, loss = 0.03905549
# Iteration 157, loss = 0.03868352
# Iteration 158, loss = 0.03831526
# Iteration 159, loss = 0.03799666
# Iteration 160, loss = 0.03761850
# Iteration 161, loss = 0.03726605
# Iteration 162, loss = 0.03693075
# Iteration 163, loss = 0.03661512
# Iteration 164, loss = 0.03630071
# Iteration 165, loss = 0.03598962
# Iteration 166, loss = 0.03565742
# Iteration 167, loss = 0.03535713
# Iteration 168, loss = 0.03506144
# Iteration 169, loss = 0.03477039
# Iteration 170, loss = 0.03448514
# Iteration 171, loss = 0.03420309
# Iteration 172, loss = 0.03391563
# Iteration 173, loss = 0.03365065
# Iteration 174, loss = 0.03339525
# Iteration 175, loss = 0.03313247
# Iteration 176, loss = 0.03287712
# Iteration 177, loss = 0.03264616
# Iteration 178, loss = 0.03238616
# Iteration 179, loss = 0.03214853
# Iteration 180, loss = 0.03190892
# Iteration 181, loss = 0.03166141
# Iteration 182, loss = 0.03142239
# Iteration 183, loss = 0.03119916
# Iteration 184, loss = 0.03100209
# Iteration 185, loss = 0.03079213
# Iteration 186, loss = 0.03055036
# Iteration 187, loss = 0.03036552
# Iteration 188, loss = 0.03015788
# Iteration 189, loss = 0.02994729
# Iteration 190, loss = 0.02974343
# Iteration 191, loss = 0.02956801
# Iteration 192, loss = 0.02938164
# Iteration 193, loss = 0.02918047
# Iteration 194, loss = 0.02898752
# Iteration 195, loss = 0.02880240
# Iteration 196, loss = 0.02862542
# Iteration 197, loss = 0.02848260
# Iteration 198, loss = 0.02829825
# Iteration 199, loss = 0.02813872
# Iteration 200, loss = 0.02798404
# Iteration 201, loss = 0.02780562
# Iteration 202, loss = 0.02765552
# Iteration 203, loss = 0.02745574
# Iteration 204, loss = 0.02730653
# Iteration 205, loss = 0.02715636
# Iteration 206, loss = 0.02699110
# Iteration 207, loss = 0.02686147
# Iteration 208, loss = 0.02668609
# Iteration 209, loss = 0.02653993
# Iteration 210, loss = 0.02639599
# Iteration 211, loss = 0.02625514
# Iteration 212, loss = 0.02610985
# Iteration 213, loss = 0.02598288
# Iteration 214, loss = 0.02586239
# Iteration 215, loss = 0.02571557
# Iteration 216, loss = 0.02557603
# Iteration 217, loss = 0.02544338
# Iteration 218, loss = 0.02532375
# Iteration 219, loss = 0.02522447
# Iteration 220, loss = 0.02507471
# Iteration 221, loss = 0.02495529
# Iteration 222, loss = 0.02481871
# Iteration 223, loss = 0.02470893
# Iteration 224, loss = 0.02458077
# Iteration 225, loss = 0.02447988
# Iteration 226, loss = 0.02436801
# Iteration 227, loss = 0.02424808
# Iteration 228, loss = 0.02413941
# Iteration 229, loss = 0.02405076
# Iteration 230, loss = 0.02392150
# Iteration 231, loss = 0.02379663
# Iteration 232, loss = 0.02371689
# Iteration 233, loss = 0.02364540
# Iteration 234, loss = 0.02347331
# Iteration 235, loss = 0.02341196
# Iteration 236, loss = 0.02330335
# Iteration 237, loss = 0.02320116
# Iteration 238, loss = 0.02309216
# Iteration 239, loss = 0.02298912
# Iteration 240, loss = 0.02287666
# Iteration 241, loss = 0.02279880
# Iteration 242, loss = 0.02271018
# Iteration 243, loss = 0.02262997
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.

# %%
predictions = np.concatenate(predictions, axis=0)

# %% [markdown]
# #### Métricas de desempenho:

# %%
## Medida da acurácia no treino:
accuracy = np.where(predictions==treino['class'], 1, 0).sum() / float(len(treino))
print(accuracy)
# Out:
# 0.992827868852

# %%
## Matriz confusão para o conjunto de treino:
print(metrics.confusion_matrix(treino['class'], predictions))
# Out:
# [[484   4]
#  [  3 485]]

# %%
## Matriz confusão para o conjunto de teste:
teste_predictions = neural_clf.predict(teste[features])
print(metrics.confusion_matrix(teste['class'],teste_predictions))
# Out:
# [[122   0]
#  [  0 122]]

# %%
## Gráfico da função perda para o classificador já treinado:
plt.figure(figsize=(5,3))
plt.suptitle(neural_clf.loss)
plt.plot(neural_clf.loss_curve_)
#plt.plot(neural_clf.loss_curve_)

# %% [markdown]
# ### 2.2 Comparação do desempenho do classificador MLP com diferentes parâmetros <a class="anchor" id="2.2"></a>
# Nesta etapa, deseja-se comparar o desempenho do classificador baseado em rede neural utilizando-se diferentes parâmetros do MLP, implementado via Scikit-Learning. Os classificadores são definidos em um único bloco e a análise do melhor parâmetro é dada através da interpretação do gráfico da função perda.
#
# Referências:
# 1.https://plot.ly/scikit-learn/plot-mlp-training-curves/
# 2.http://scikit-learn.org/stable/auto_examples/neural_networks/plot_mlp_training_curves.html

# %%
## Inicializando os parâmetros:
params=[]
labels=[]
plot_args=[]

# %% [markdown]
# #### A. Em relação à atualização da taxa de aprendizado e emprego de *momento*:

# %%
## Definição dos meios de atualização da taxa de aprendizado: 
params.append([{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': 0,
           'learning_rate_init': 0.01, 'activation': 'logistic'},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'logistic'},
          {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.01, 'activation': 'logistic'},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': 0,
           'learning_rate_init': 0.01, 'activation': 'logistic'},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'logistic'},
          {'solver': 'sgd', 'learning_rate': 'invscaling', 'momentum': .9,
           'nesterovs_momentum': True, 'learning_rate_init': 0.01, 'activation': 'logistic'}])

labels.append(["constant", "constant & momentum",
             "constant & Nesterov's",
             "inv-scaling", "inv-scaling & momentum",
             "inv-scaling & Nesterov's"])

plot_args.append([{'c': 'red', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'blue', 'linestyle': '-'},
             {'c': 'red', 'linestyle': '--'},
             {'c': 'green', 'linestyle': '--'},
             {'c': 'blue', 'linestyle': '--'}])

# %% [markdown]
# #### B. Em relação à taxa de aprendizado inicial:

# %%
## Definição dos meios de atualização da taxa de aprendizado: 
params.append([{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.001, 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.1, 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.5, 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 1, 'activation': 'logistic'},])

labels.append(["eta = 0.001", "eta = 0.01",
            "eta = 0.1", "eta = 0.5", 
            "eta = 1"])

plot_args.append([{'c': 'red', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'blue', 'linestyle': '-'},
             {'c': 'black', 'linestyle': '--'},
             {'c': 'purple', 'linestyle': '--'}])

# %% [markdown]
# #### C. Em relação às camadas ocultas e o número de neurônios:

# %%
## Definição dos meios de atualização da taxa de aprendizado: 
params.append([{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9, 'nesterovs_momentum': False, 
           'learning_rate_init': 0.01, 'hidden_layer_sizes':(4,4), 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9, 'nesterovs_momentum': False, 
           'learning_rate_init': 0.01, 'hidden_layer_sizes':(4,10), 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9, 'nesterovs_momentum': False, 
           'learning_rate_init': 0.01, 'hidden_layer_sizes':(10,10), 'activation': 'logistic'},
             {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9, 'nesterovs_momentum': False, 
           'learning_rate_init': 0.01, 'hidden_layer_sizes':(40,10), 'activation': 'logistic'},
            {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9, 'nesterovs_momentum': False, 
           'learning_rate_init': 0.01, 'hidden_layer_sizes':(40,40), 'activation': 'logistic'}])

labels.append(["hidden=(4,4)", "hidden=(4,10)",
            "hidden=(10,10)", "hidden=(40,10)",
            "hidden=(40,40)"])

plot_args.append([{'c': 'red', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'blue', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '--'},
             {'c': 'blue', 'linestyle': '--'}])

# %% [markdown]
# #### D. Em relação às funções de ativação:

# %%
## Definição dos meios de atualização da taxa de aprendizado: 
params.append([{'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'identity'},
            {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'logistic'},
            {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'tanh'},
            {'solver': 'sgd', 'learning_rate': 'constant', 'momentum': .9,
           'nesterovs_momentum': False, 'learning_rate_init': 0.01, 'activation': 'relu'}])

labels.append(["identity", "logistic", "tanh", "relu"])

plot_args.append([{'c': 'red', 'linestyle': '-'},
             {'c': 'green', 'linestyle': '-'},
             {'c': 'blue', 'linestyle': '-'},
             {'c': 'black', 'linestyle': '-'}])

# %%
## Subtítulos dos gráficos da análise abaixo:
nomes = ['Learning rate type and Momentum',
         'Initial learning rate',
         'hidden_layer_sizes', 
         'activation_function']

# %%
def plot_on_dataset(treino, ax, name, ix):
    #print("\nlearning on dataset %s" % name)
    ax.set_title(name)
    mlps = []
    max_iter = 400

    for label, param in zip(labels[ix], params[ix]):
        train_predictors = (treino[features].iloc[train,:])  # The predictors we're using the train the algorithm.
        train_target = treino['class'].iloc[train]            # The target we're using to train the algorithm.
        
        #print("training: %s" % label)
        mlp = MLPClassifier(verbose=0, random_state=0,
                            max_iter=max_iter, **param)
        mlp.fit(train_predictors, train_target)
        mlps.append(mlp)
        #print("Training set score: %f" % mlp.score(train_predictors, train_target))
        #print("Training set loss: %f" % mlp.loss_)
    for mlp, label, args in zip(mlps, labels[ix], plot_args[ix]):
            ax.plot(mlp.loss_curve_, label=label, **args)
            ax.set_xlabel='epoch'
            ax.set_ylabel='loss'
            ax.legend(loc="best")

# %% [markdown]
# #### Análise do resultado:

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
for ax, name, ix in zip(axes.ravel(), nomes, np.arange(0,4)):
    plot_on_dataset(treino, ax=ax, name=name, ix=ix)
# Out:
# /home/anaconda3/envs/python3/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)

# %% [markdown]
# ## III. Classificador baseado em sistemas fuzzy <a class="anchor" id="III"></a>
# Referências:
# - http://pythonhosted.org/scikit-fuzzy/install.html
# - http://pythonhosted.org/scikit-fuzzy/_downloads/plot_tipping_problem_newapi.py

# %% [markdown]
# #### Nota de aula (20.04.2017):
# Para criar o particionamento dos conjuntos fuzzy pode ser utilizado o agrupamento dos dados. A  Profa. Myriam dá o exemplo com a dispersão de duas classes (R2) e da projeção dos pontos em cada eixo considerado. [Um colega utilizou a análise de percentil...]
#
# A Profa. Myriam fala sobre o conhecimento de domínio para a determinação da semântica dos conjuntos. Por exemplo, na aplicação vou saber denominar as partições do conjunto em "baixa, média e alta", por exemplo.
# --> Importante: no particionamento é muito importante não deixar gaps entre as semânticas. Pois senão a regra ficará sempre com 0

# %%
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %% [markdown]
# #### Definição do problema:
# We would formulate this problem as:
#
# * Antecednets (Inputs)
#    - `service`
#       * Universe (ie, crisp value range): How good was the service of the wait
#         staff, on a scale of 0 to 10?
#       * Fuzzy set (ie, fuzzy value range): poor, acceptable, amazing
#    - `food quality`
#       * Universe: How tasty was the food, on a scale of 0 to 10?
#       * Fuzzy set: bad, decent, great
# * Consequents (Outputs)
#    - `tip`
#       * Universe: How much should we tip, on a scale of 0% to 25%
#       * Fuzzy set: low, medium, high
# * Rules
#    - IF the *service* was good  *or* the *food quality* was good,
#      THEN the tip will be high.
#    - IF the *service* was average, THEN the tip will be medium.
#    - IF the *service* was poor *and* the *food quality* was poor
#      THEN the tip will be low.
# * Usage
#    - If I tell this controller that I rated:
#       * the service as 9.8, and
#       * the quality as 6.5,
#    - it would recommend I leave:
#       * a 20.2% tip.

# %%
sns.pairplot?

# %%
## Gerando novamente o pairplot para visão geral do conjunto de TREINO, mantendo o eixo em cada subgráfico:
g = sns.pairplot(treino, hue="class", vars=['varCWT', 'skewCWT', 'curtCWT', 'entropy'])
for ax in g.axes.flat:
    _ = plt.setp(ax.get_xticklabels(), visible=True)

# %%
treino.describe()
# Out:
#            level_0        index      varCWT     skewCWT     curtCWT  \
# count   976.000000   976.000000  976.000000  976.000000  976.000000
# mean    704.713115   722.271516    0.235903    1.530096    1.555336
# std     394.240124   401.962497    2.889026    5.969058    4.502094
# min       3.000000     3.000000   -7.036400  -13.677900   -5.261300
# 25%     365.750000   378.750000   -1.939400   -2.227100   -1.633225
# 50%     737.000000   761.000000    0.179130    1.963750    0.616630
# 75%    1052.250000  1076.250000    2.669125    6.412150    3.663950
# max    1347.000000  1371.000000    6.824800   12.951600   17.677200
#
#           entropy       class
# count  976.000000  976.000000
# mean    -1.167882    0.500000
# std      2.109773    0.500256
# min     -8.548200    0.000000
# 25%     -2.382450    0.000000
# 50%     -0.586000    0.500000
# 75%      0.418413    1.000000
# max      2.154700    1.000000

# %%
varCWT.automf?

# %%
varCWT = ctrl.Antecedent(treino['varCWT'], 'varCWT')
skewCWT = ctrl.Antecedent(treino['skewCWT'], 'skewCWT')
curtCWT = ctrl.Antecedent(treino['curtCWT'], 'curtCWT')
classiFuzzy = ctrl.Consequent([0,1], 'class')

# %%
varCWT.automf(number=3, variable_type='quality', names=['desfav', 'indif', 'fav'])
skewCWT.automf(number=3, variable_type='quality', names=['desfav', 'indif', 'fav'])
curtCWT.automf(number=3, variable_type='quality', names=['desfav', 'indif', 'fav'])

# %%
# Custom membership functions can be built interactively with a familiar,
# Pythonic API
#classiFuzzy['autentico'] = fuzz.trimf(classiFuzzy.universe, [1, 1, 1])
#classiFuzzy['falso'] = fuzz.trimf(tip.universe, [0, 13, 25])
classiFuzzy['autentico'] = [0,1]
classiFuzzy['falso'] = [1,0]

# %%
## Visualização das variáveis fuzzy:
varCWT['desfav'].view()
# Out:
# /home/anaconda3/envs/python3/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
curtCWT.view()
# Out:
# /home/anaconda3/envs/python3/lib/python3.5/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
tip.view()

# %%
"""Fuzzy rules
-----------

Now, to make these triangles useful, we define the *fuzzy relationship*
between input and output variables. For the purposes of our example, consider
three simple rules:

1. If the food is poor OR the service is poor, then the tip will be low
2. If the service is average, then the tip will be medium
3. If the food is good OR the service is good, then the tip will be high.

Most people would agree on these rules, but the rules are fuzzy. Mapping the
imprecise rules into a defined, actionable tip is a challenge. This is the
kind of task at which fuzzy logic excels.
"""

rule1 = ctrl.Rule(quality['poor'] | service['poor'], tip['low'])
rule2 = ctrl.Rule(service['average'], tip['medium'])
rule3 = ctrl.Rule(service['good'] | quality['good'], tip['high'])

# %%
"""Control System Creation and Simulation
---------------------------------------

Now that we have our rules defined, we can simply create a control system
via:
"""

tipping_ctrl = ctrl.ControlSystem([rule1, rule2, rule3])

# %%
"""
In order to simulate this control system, we will create a
``ControlSystemSimulation``.  Think of this object representing our controller
applied to a specific set of cirucmstances.  For tipping, this might be tipping
Sharon at the local brew-pub.  We would create another
``ControlSystemSimulation`` when we're trying to apply our ``tipping_ctrl``
for Travis at the cafe because the inputs would be different.
"""

tipping = ctrl.ControlSystemSimulation(tipping_ctrl)

# %%
"""
We can now simulate our control system by simply specifying the inputs
and calling the ``compute`` method.  Suppose we rated the quality 6.5 out of 10
and the service 9.8 of 10.
"""
# Pass inputs to the ControlSystem using Antecedent labels with Pythonic API
# Note: if you like passing many inputs all at once, use .inputs(dict_of_data)
tipping.input['quality'] = 0.9
tipping.input['service'] = 7.8

# %%
# Crunch the numbers
tipping.compute()

# %%
"""
Once computed, we can view the result as well as visualize it.
"""
print(tipping.output['tip'])
tip.view(sim=tipping)

# %%
"""
.. image:: PLOT2RST.current_figure

The resulting suggested tip is **20.24%**.

Final thoughts
--------------

The power of fuzzy systems is allowing complicated, intuitive behavior based
on a sparse system of rules with minimal overhead. Note our membership
function universes were coarse, only defined at the integers, but
``fuzz.interp_membership`` allowed the effective resolution to increase on
demand. This system can respond to arbitrarily small changes in inputs,
and the processing burden is minimal.

"""
