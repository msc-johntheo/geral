# %%
from numpy import genfromtxt

col_data = open('col.txt')
siebel_data = open('siebel.txt')

for c in col_data:
    if c in siebel_data:
        print('{} - SIM'.format(c))
    else:
        print('{} - NAO'.format(c))
# Out:
# SBO-812FO1MS90-013
#  - SIM
# OCO-812FEYMUJN-013
#  - NAO
# SPO-812FD5XNYQ-013
#  - NAO
# BHE-812FCYQXZR-013
#  - NAO
# MGA-812FBHVFQO-013
#  - NAO
# SPO-812FBRR2G6-013
#  - NAO
# SMA-812FBTUBNP-013
#  - NAO
# SPO-812FNL8JRG-013
#  - NAO
# SPO-812FB370HG-013
#  - NAO
# SPO-812FB12FIF-013
#  - NAO
# SPO-812FNDOT0A-013
#  - NAO
# SJC-812FD4HVUH-013
#  - NAO
# SVE-812FK60A08-013
#  - NAO
# JAI-812FBJUA0H-013
#  - NAO
# CTA-812FD8EMZ2-013
#  - NAO
# SNE-812FDZQCNU-013
#  - NAO
# SPO-812FO2RMQV-013
#  - NAO
# ITA-812FP7ZUTS-013
#  - NAO
# SPO-812FC2091N-013
#  - NAO
# PAC-812FLEEUK3-013
#  - NAO
# PAE-812FCR8JZI-013
#  - NAO
# OCO-812FEXWULR-013
#  - NAO
# OLD-812FNKKTJS-013
#  - NAO
# VSA-812FJEAB85-013
#  - NAO
# SJC-812FC3ALSN-013
#  - NAO
# GNA-812FQL2VHM-013
#  - NAO
# RJO-812FQCPP60-013
#  - NAO
# RJO-812FEBNA3I-013
#  - NAO
# SJC-812FECEOQY-013
#  - NAO
# CAS-812FB2RNXB-013
#  - NAO
# SPO-812FCB4VV0-013
#  - NAO
# SPO-812FC804C8-013
#  - NAO
# FLA-812FDBTBZU-013
#  - NAO
# ...
